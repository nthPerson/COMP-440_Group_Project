# %% [markdown]
# # Sample Data Generation Notebook

# %% [markdown]
# ##### Get usernames and categories

# %%
# Dependencies: pip install python-dotenv Flask Flask-SQLAlchemy
import os
import sys
from pathlib import Path
from dotenv import load_dotenv
from flask import Flask

# Load backend/.env
load_dotenv(".env")

# Initialize Flask + SQLAlchemy
from models import db, User, Category  # uses the User and Category table from MySQL db
app = Flask(__name__)
app.config.update(
    # SQLALCHEMY_DATABASE_URI=os.getenv("DATABASE_URL") or os.getenv("DATABASE_URL"),
    SQLALCHEMY_DATABASE_URI=os.getenv("SHARED_DATABASE_URL") or os.getenv("DATABASE_URL"),
    SQLALCHEMY_TRACK_MODIFICATIONS=False,
)
db.init_app(app)

# Query users and categories
usernames, categories = [], []
with app.app_context():
    usernames = [u.username for u in User.query.order_by(User.username).all()]
    categories = [c.name for c in Category.query.order_by(Category.name).all()]

print(f"Found {len(usernames)} users")
print(usernames)
print(f"Found {len(categories)} categories")
print(categories[:10])
# Out:
# Found 14 users
# ['admin', 'bellaffelipe', 'BillyGarcia', 'ChristineNguyen', 'd_trump', 'dollheartz', 'elon_musk', 'FrostyBite', 'Gigi', 'karen_poor_reviews', 'nthPerson', 'PerryLee', 'RobertSlay', 'techy']
# Found 103 categories
# ['3d printers', 'accessories', 'accessory', 'ai', 'animals', 'apple', 'apps & games', 'arts', 'automotive', 'baby']

# %% [markdown]
# ##### Print usernames and categories

# %%
for i, user in enumerate(usernames):
    print(f'User {i}: {user}')

print(f'Categories ({len(categories)}): {categories}')
# Out:
# User 0: admin
# User 1: bellaffelipe
# User 2: BillyGarcia
# User 3: ChristineNguyen
# User 4: d_trump
# User 5: dollheartz
# User 6: elon_musk
# User 7: FrostyBite
# User 8: Gigi
# User 9: karen_poor_reviews
# User 10: nthPerson
# User 11: PerryLee
# User 12: RobertSlay
# User 13: techy
# Categories (103): ['3d printers', 'accessories', 'accessory', 'ai', 'animals', 'apple', 'apps & games', 'arts', 'automotive', 'baby', 'bath', 'beauty', 'bedding', 'bikes', 'board games', 'books', 'bunnies', 'cameras', 'camping & hiking', 'car', 'car seats', 'cars', 'cell phone', 'cell phones', 'cellphone', 'cellphones', 'cleaning supplies', 'clothes', 'clothing', 'collectibles', 'computers', 'costumes', 'crafts', 'diy', 'drones', 'educational toys', 'electronics', 'entertainment', 'fishing', 'fitness', 'furniture', 'games', 'garden', 'gift cards', 'grocery', 'gym wear', 'handmade', 'hardware', 'headphones', 'health', 'home', 'home improvement', 'industrial', 'jewelry', 'keyboard', 'kitchen', 'lighting', 'luggage', 'luxury items', 'magazines', "men's apparel", 'mobile', 'mobiles', 'monitor', 'movies', 'music', 'musical instruments', 'nursery', 'office supplies', 'outdoor activites', 'outdoor activities', 'outdoors', 'overly-priced-china-stuff', 'party supplies', 'personal care', 'pet supplies', 'phones', 'puzzles', 'robots', 'school supplies', 'scientific', 'scooters', 'seasonal', 'security systems', 'shoes', 'skateboards', 'smart home', 'smart watches', 'software', 'sports', 'storage & organization', 'streaming devices', 'strollers', 'technology', 'tools', 'toys', 'travel', 'vehicle', 'vehicles', 'video games', 'watches', "women's apparel", 'work gear']

# %% [markdown]
# ##### Generate sample data using OpenAI API
# -- 2nd Version of Item Sample Generation Cell
# <br>Instead of making a single call to the OpenAI API to generate items, this version batches the number of requested samples and collects them all in `generated_items`.

# %%
import os
import json
import random
import re
import time
from datetime import date
from decimal import Decimal, ROUND_HALF_UP
from openai import OpenAI

# Set OpenAI API key
load_dotenv(".env")
OPENAI_API_KEY = os.getenv('OPENAI_PERSONAL_KEY')

# Instantiate client
client = OpenAI(api_key=OPENAI_API_KEY, project='proj_tKtmc8cXcBHwbMO9uMLyAJum')  # Personal key, COMP440 Online Shop project

def generate_items_with_llm(usernames, categories, n=100, per_call=12, max_calls=500, sleep_s=0.25):
    # Helpers
    def norm_price(val):
        dec = Decimal(str(val)).quantize(Decimal("0.01"), rounding=ROUND_HALF_UP)
        return str(dec)

    def is_recent_iso(d):
        try:
            y, m, d0 = map(int, d.split("-"))
            _ = date(y, m, d0)
            return True
        except Exception:
            return False

    def normalize_title(t: str) -> str:
        t = t.lower().strip()
        t = re.sub(r"[^a-z0-9\s]+", "", t)
        t = re.sub(r"\s+", " ", t)
        return t[:255]

    def diversify_item(item, attempt):
        # Light, safe variations to reduce near-duplicates while keeping schema intact
        title = item["title"]
        desc = item["description"]

        suffixes = [" Pro", " Plus", " Max", " Mini", " Lite", " SE", " Edition", " Bundle", " Kit", " Set"]
        extras = [
            "Includes original packaging.",
            "Ships quickly and well-protected.",
            "Gently used and fully functional.",
            "Comes with a protective case.",
            "Clean and well-maintained.",
            "Limited-time price.",
            "Tested before listing.",
        ]
        # Vary title by appending a suffix not already present
        for sfx in random.sample(suffixes, k=min(3, len(suffixes))):
            if sfx.lower() not in title.lower() and len(title) + len(sfx) <= 255:
                title = title + sfx
                break

        # Optionally tweak description with a short factual line
        if len(desc.split(".")) <= 3:
            extra = random.choice(extras)
            if extra not in desc:
                desc = (desc.rstrip().rstrip(".") + ". " + extra).strip()

        item["title"] = title
        item["description"] = desc
        return item

    system_msg = (
        "You are a data generation assistant. "
        "Return ONLY compact JSON that strictly matches the requested schema. "
        "No commentary. No markdown. No extra keys. "
        "Ensure high diversity in titles and descriptions. Avoid near-duplicates."
    )

    base_prompt = (
        "Generate realistic sample items. "
        "Output strictly as JSON with this shape: "
        '{ "items": [ { "title": str, "description": str, "price": number, "date_posted": "YYYY-MM-DD", '
        '"posted_by": str, "categories": [str, ...] } ] }'
    )

    out = []
    usernames_set = set(usernames)
    categories_set = set(categories)
    used_keys = set()  # (norm_title, posted_by)

    calls = 0
    while len(out) < n and calls < max_calls:
        calls += 1
        batch_target = min(per_call, n - len(out))
        # Pass a rolling window of recently used titles to discourage repeats across calls
        avoid_titles = [i["title"] for i in out[-200:]]

        user_payload = {
            "instructions": {
                "count": batch_target,
                "rules": [
                    "Each item must use posted_by from the provided usernames list.",
                    "Each item must have categories as 1 to 3 distinct names from the provided categories list.",
                    "Do NOT include star_rating or image_url fields.",
                    "price must be a positive number with two decimals, typically 5.00 to 5000.00.",
                    "date_posted must be an ISO date (YYYY-MM-DD) within the last 120 days.",
                    "title should be short and realistic for an online marketplace.",
                    "description should be 1-2 sentences with realistic details.",
                    "Avoid titles in avoid_titles and avoid near-duplicate wording.",
                    "Vary brands/models/materials/colors/conditions to increase diversity."
                ],
            },
            "fields_schema": {
                "title": "string",
                "description": "string",
                "price": "number(2-decimals)",
                "date_posted": "YYYY-MM-DD",
                "posted_by": "string from usernames",
                "categories": "array of 1-3 strings from categories"
            },
            "usernames": usernames,
            "categories": categories,
            "avoid_titles": avoid_titles
        }

        try:
            resp = client.chat.completions.create(
                model="gpt-4o-mini",
                temperature=0.8,  # slightly higher for diversity
                messages=[
                    {"role": "system", "content": system_msg},
                    {"role": "user", "content": base_prompt},
                    {"role": "user", "content": json.dumps(user_payload)}
                ]
            )
            content = resp.choices[0].message.content.strip()
            data = json.loads(content)
            items = data.get("items", [])
        except Exception:
            items = []

        for raw in items:
            # Validate core fields
            if raw.get("posted_by") not in usernames_set:
                continue
            cats = raw.get("categories") or []
            cats = [c for c in cats if c in categories_set]
            if not (1 <= len(cats) <= 3):
                continue
            if not isinstance(raw.get("price"), (int, float, str)):
                continue
            if not (isinstance(raw.get("title"), str) and isinstance(raw.get("description"), str)):
                continue
            if not (isinstance(raw.get("date_posted"), str) and is_recent_iso(raw["date_posted"])):
                continue

            item = {
                "title": raw["title"].strip()[:255],
                "description": raw["description"].strip(),
                "price": norm_price(raw["price"]),
                "date_posted": raw["date_posted"],
                "posted_by": raw["posted_by"],
                "categories": cats
            }

            # Uniqueness: norm(title)+posted_by
            attempts = 0
            while attempts < 3:
                key = (normalize_title(item["title"]), item["posted_by"])
                if key not in used_keys:
                    break
                attempts += 1
                item = diversify_item(item, attempts)

            # Final check
            key = (normalize_title(item["title"]), item["posted_by"])
            if key in used_keys:
                continue

            out.append(item)
            used_keys.add(key)

            if len(out) >= n:
                break

        if len(out) < n:
            time.sleep(sleep_s)  # gentle throttle/backoff between calls

    return out

# Request as many unique items as you want (e.g., 100+)
generated_items = generate_items_with_llm(usernames, categories, n=100, per_call=12)
print(f"Generated {len(generated_items)} unique items (in {len({(i['posted_by'], i['title']) for i in generated_items})} unique title/seller pairs).")
for i, it in enumerate(generated_items[:5], 1):
    print(i, it)
# Out:
# Generated 100 unique items (in 100 unique title/seller pairs).
# 1 {'title': 'Vintage Camera', 'description': 'A classic 35mm film camera in excellent condition, perfect for photography enthusiasts.', 'price': '250.00', 'date_posted': '2023-09-15', 'posted_by': 'ChristineNguyen', 'categories': ['cameras', 'collectibles']}
# 2 {'title': 'Mountain Bike', 'description': 'High-performance mountain bike, lightly used, ideal for rugged terrains and outdoor adventures.', 'price': '500.00', 'date_posted': '2023-08-20', 'posted_by': 'BillyGarcia', 'categories': ['bikes', 'outdoor activities']}
# 3 {'title': 'Wireless Headphones', 'description': 'Bluetooth headphones with noise cancellation and long battery life, great for music lovers.', 'price': '89.99', 'date_posted': '2023-10-01', 'posted_by': 'FrostyBite', 'categories': ['electronics', 'headphones']}
# 4 {'title': 'Gaming Chair', 'description': 'Ergonomic gaming chair with adjustable features, designed for comfort during long gaming sessions.', 'price': '175.00', 'date_posted': '2023-09-10', 'posted_by': 'd_trump', 'categories': ['furniture']}
# 5 {'title': 'Baby Stroller', 'description': 'Lightweight and compact stroller for easy travel with your little one, in great condition.', 'price': '120.00', 'date_posted': '2023-08-30', 'posted_by': 'Gigi', 'categories': ['baby', 'strollers']}

# %% [markdown]
# ##### Build SQL to insert generated items into `item`

# %%
# Copy the output into MySQL Workbench and run.
from decimal import Decimal

def sql_quote(s: str) -> str:
    if s is None:
        return "NULL"
    s = str(s).replace("\\", "\\\\").replace("'", "''").replace("\n", " ")
    return f"'{s}'"

def dec2(val) -> str:
    return str(Decimal(str(val)).quantize(Decimal("0.01")))

lines = []
lines.append("-- Insert generated items")
lines.append("START TRANSACTION;")
for it in generated_items:
    title = sql_quote(it["title"])
    desc = sql_quote(it["description"])
    date_posted = sql_quote(it["date_posted"])  # 'YYYY-MM-DD'
    price = dec2(it["price"])                   # numeric literal, no quotes
    posted_by = sql_quote(it["posted_by"])
    lines.append(
        f"INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) "
        # f"INSERT INTO comp440db.item (`title`, `description`, `date_posted`, `price`, `posted_by`) "
        f"VALUES ({title}, {desc}, {date_posted}, {price}, {posted_by});"
    )
lines.append("COMMIT;")

sql_insert_items = "\n".join(lines)
print(sql_insert_items)
# Out:
# -- Insert generated items
# START TRANSACTION;
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Vintage Camera', 'A classic 35mm film camera in excellent condition, perfect for photography enthusiasts.', '2023-09-15', 250.00, 'ChristineNguyen');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Mountain Bike', 'High-performance mountain bike, lightly used, ideal for rugged terrains and outdoor adventures.', '2023-08-20', 500.00, 'BillyGarcia');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Wireless Headphones', 'Bluetooth headphones with noise cancellation and long battery life, great for music lovers.', '2023-10-01', 89.99, 'FrostyBite');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Gaming Chair', 'Ergonomic gaming chair with adjustable features, designed for comfort during long gaming sessions.', '2023-09-10', 175.00, 'd_trump');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Baby Stroller', 'Lightweight and compact stroller for easy travel with your little one, in great condition.', '2023-08-30', 120.00, 'Gigi');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Smart Watch', 'Feature-rich smartwatch with fitness tracking and notifications, barely used and in like-new condition.', '2023-09-22', 199.99, 'PerryLee');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Fitness Tracker', 'Water-resistant fitness tracker with heart rate monitor and step counter, ideal for fitness enthusiasts.', '2023-09-18', 59.99, 'dollheartz');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Board Game Set', 'Complete set of classic board games, perfect for family game nights or gatherings.', '2023-08-25', 45.00, 'nthPerson');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Children''s Books', 'A collection of children''s books, gently used, suitable for ages 5-10.', '2023-09-12', 30.00, 'RobertSlay');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Electric Guitar', 'Beginner-friendly electric guitar with accessories, perfect for aspiring musicians.', '2023-09-28', 220.00, 'admin');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Pet Supplies Bundle', 'Includes toys, food, and grooming supplies for your furry friend, a great deal.', '2023-08-15', 75.00, 'karen_poor_reviews');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Wireless Earbuds', 'Experience exceptional sound quality with these sleek wireless earbuds. Ideal for music lovers on the go.', '2023-09-15', 89.99, 'dollheartz');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Camping Tent', 'Lightweight and durable camping tent perfect for all your outdoor adventures. Easy to set up and pack away.', '2023-10-02', 149.50, 'FrostyBite');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Art Supplies Kit', 'Complete art supplies kit including paints, brushes, and canvases for budding artists.', '2023-09-25', 45.00, 'karen_poor_reviews');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Smartphone Stand', 'Adjustable smartphone stand for hands-free video calls and viewing. Compact and portable.', '2023-08-30', 25.99, 'BillyGarcia');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Electric Kettle', 'Quickly boil water with this energy-efficient electric kettle. Features auto shut-off for safety.', '2023-09-10', 39.99, 'ChristineNguyen');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Yoga Mat', 'Non-slip yoga mat providing great cushioning for all types of workouts. Lightweight and portable.', '2023-09-20', 29.99, 'PerryLee');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('LED Desk Lamp', 'Stylish LED desk lamp with adjustable brightness and color temperatures for your workspace.', '2023-09-05', 65.00, 'elon_musk');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Puzzle Game', 'Engaging puzzle game for family game nights, featuring colorful pieces and fun themes.', '2023-09-12', 22.50, 'techy');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Garden Tools Set', 'Complete garden tools set including pruners, trowel, and gloves for easy gardening.', '2023-09-18', 34.99, 'RobertSlay');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Luxury Watch', 'Elegant luxury watch with a stainless steel band and water-resistant features. Perfect for any occasion.', '2023-10-01', 299.99, 'nthPerson');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Drone with Camera', 'High-quality drone equipped with a 4K camera for breathtaking aerial photography.', '2023-09-22', 499.99, 'admin');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Children''s Educational Toys', 'Fun and interactive educational toys designed to enhance learning and creativity for kids.', '2023-09-28', 55.00, 'Gigi');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Portable 3D Printer', 'Compact and lightweight, ideal for on-the-go printing. Includes Wi-Fi connectivity and a starter filament pack.', '2023-09-15', 299.99, 'ChristineNguyen');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Stylish Laptop Backpack', 'Durable fabric with multiple compartments for laptops and accessories. Perfect for students and professionals.', '2023-08-20', 89.50, 'd_trump');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Wireless Bluetooth Speaker', 'High-quality sound with a sleek design. Perfect for outdoor events or home use.', '2023-09-01', 129.99, 'elon_musk');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Garden Patio Set', 'Elegant outdoor furniture set including a table and four chairs, perfect for entertaining guests.', '2023-07-30', 479.00, 'BillyGarcia');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Camping Hammock', 'Lightweight and easy to set up, perfect for relaxing outdoors. Comes with portable carrying case.', '2023-08-05', 45.75, 'PerryLee');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Kids'' Educational Puzzle', 'Fun and engaging puzzle that helps develop cognitive skills. Suitable for ages 4 and up.', '2023-09-10', 29.99, 'dollheartz');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Coffee Maker with Grinder', 'Brew fresh coffee with built-in grinder for the ultimate flavor experience. Easy to clean and operate.', '2023-08-15', 149.99, 'Gigi');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Crafting Supplies Bundle', 'Includes a variety of materials perfect for DIY projects. Great for hobbyists and crafters.', '2023-09-25', 65.50, 'nthPerson');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Smartphone Tripod', 'Sturdy and adjustable tripod for capturing perfect photos and videos with your smartphone.', '2023-09-12', 34.99, 'RobertSlay');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Luxury Skincare Set', 'Complete set of organic skincare products designed to nourish and rejuvenate your skin.', '2023-08-28', 199.99, 'FrostyBite');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('High-Performance Drone', 'Equipped with advanced features for aerial photography and videography. Ideal for enthusiasts.', '2023-09-18', 399.00, 'techy');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Vintage Vinyl Records Collection', 'A curated collection of classic vinyl records from the 70s and 80s, perfect for collectors.', '2023-09-30', 120.00, 'admin');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Portable Phone Charger', 'Stay powered on the go with this compact and lightweight phone charger, perfect for travel.', '2023-09-15', 29.99, 'FrostyBite');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Camping Lantern', 'Brighten your campsite with this durable LED camping lantern, featuring multiple brightness settings.', '2023-08-30', 45.50, 'Gigi');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Kids'' Art Supplies', 'Inspire creativity with this bundled set of art supplies including markers, crayons, and sketch pads.', '2023-09-20', 19.75, 'ChristineNguyen');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Wireless Gaming Mouse', 'Enhance your gaming experience with this high-precision wireless gaming mouse featuring customizable buttons.', '2023-10-02', 79.99, 'BillyGarcia');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Vintage Vinyl Record Player', 'Enjoy your favorite records with this stylish vintage-inspired vinyl player, complete with built-in speakers.', '2023-09-10', 199.99, 'PerryLee');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Luxury Leather Wallet', 'Sleek and elegant, this luxury leather wallet features RFID protection and plenty of card slots.', '2023-09-25', 89.00, 'dollheartz');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Smartphone Camera Lens Kit', 'Transform your mobile photography with this lens kit that includes wide-angle and macro lenses.', '2023-09-05', 34.99, 'techy');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Outdoor Adventure Backpack', 'Ideal for hiking and camping, this waterproof backpack has ample storage and ergonomic support.', '2023-08-15', 65.00, 'elon_musk');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Bluetooth Wireless Earphones', 'Experience crystal-clear sound with these wireless earphones, perfect for workouts and commuting.', '2023-09-08', 54.99, 'RobertSlay');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Garden Composter Bin', 'Turn kitchen scraps into nutrient-rich compost with this eco-friendly garden composter bin.', '2023-09-12', 120.00, 'd_trump');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Electric Pressure Cooker', 'Cook meals faster with this versatile electric pressure cooker featuring multiple cooking modes.', '2023-10-01', 149.99, 'nthPerson');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Adult Coloring Book', 'Relax and unwind with this beautifully illustrated adult coloring book designed for stress relief.', '2023-09-22', 15.00, 'karen_poor_reviews');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('3D Printer PLA Filament', 'High-quality PLA filament for 3D printers. Available in various colors.', '2023-09-15', 29.99, 'BillyGarcia');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Camping Backpack 50L', 'Durable and spacious backpack perfect for hiking and camping trips.', '2023-08-20', 89.50, 'FrostyBite');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Wireless Gaming Headset', 'Immerse yourself in the game with this comfortable wireless headset.', '2023-09-10', 75.00, 'Gigi');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Electric Scooter', 'Eco-friendly electric scooter with a range of 30 miles on a single charge.', '2023-09-05', 349.99, 'elon_musk');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Portable Projector', 'Compact projector for outdoor movie nights or presentations.', '2023-09-01', 199.99, 'd_trump');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Stainless Steel Water Bottle', 'Stay hydrated with this durable and stylish water bottle.', '2023-08-30', 19.99, 'ChristineNguyen');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Kids Educational Puzzle', 'Fun and engaging puzzles designed to boost children''s learning.', '2023-09-12', 24.50, 'PerryLee');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Luxury Leather Backpack', 'Stylish leather backpack perfect for daily use or travel.', '2023-08-25', 159.99, 'dollheartz');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Bluetooth Soundbar', 'Enhance your audio experience with this sleek soundbar.', '2023-08-15', 120.00, 'admin');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Fitness Resistance Bands', 'Set of high-quality resistance bands for strength training at home.', '2023-09-08', 29.99, 'nthPerson');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Smart Home Security Camera', 'Keep your home safe with this easy-to-install security camera.', '2023-09-02', 89.99, 'RobertSlay');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Artisan Handmade Jewelry', 'Unique pieces of jewelry handcrafted by local artisans.', '2023-08-28', 54.99, 'techy');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Wireless Car Charger', 'This sleek, fast-charging wireless car charger is perfect for keeping your phone powered on the go. Compatible with most smartphones.', '2023-10-10', 29.99, 'ChristineNguyen');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Portable Bluetooth Speaker', 'Enjoy your favorite music anywhere with this compact and powerful portable Bluetooth speaker. Great battery life and waterproof design.', '2023-09-15', 59.99, 'FrostyBite');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Kids'' Puzzle Set', 'A fun and educational puzzle set for kids that enhances their problem-solving skills while keeping them entertained.', '2023-10-05', 19.99, 'Gigi');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Ergonomic Office Chair', 'This ergonomic office chair is designed for comfort, providing excellent support for long hours of work. Adjustable height and recline features.', '2023-08-20', 199.99, 'PerryLee');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Luxury Skincare Set', 'Pamper yourself with this comprehensive skincare set, featuring high-quality products for a radiant complexion.', '2023-09-12', 79.99, 'bellaffelipe');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('3D Printing Filament', 'High-quality PLA filament for 3D printing, available in various colors. Perfect for all your creative projects.', '2023-10-01', 24.99, 'd_trump');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Smartphone Gimbal Stabilizer', 'Take your video recording to the next level with this smartphone gimbal stabilizer, ensuring smooth and professional shots.', '2023-09-05', 129.99, 'BillyGarcia');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Leather Backpack', 'Stylish and durable leather backpack, ideal for work or travel. Multiple compartments for organization.', '2023-10-03', 149.99, 'nthPerson');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Bicycle Repair Kit', 'This comprehensive bicycle repair kit includes all tools needed for quick fixes on the road. Essential for every cyclist.', '2023-09-25', 39.99, 'RobertSlay');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Educational Board Game', 'A fun board game that combines learning with play, perfect for family game nights. Suitable for kids and adults alike.', '2023-09-20', 34.99, 'techy');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Gaming Mouse Pad', 'Enhance your gaming experience with this high-quality mouse pad that offers a smooth surface and stylish design.', '2023-09-28', 15.99, 'admin');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('High-Resolution Camera', 'Capture stunning photos with this high-resolution camera. Perfect for both amateurs and professionals alike.', '2023-09-12', 349.99, 'ChristineNguyen');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Camping Cooking Set', 'Everything you need for a great outdoor cooking experience. Lightweight and easy to pack.', '2023-10-05', 89.50, 'Gigi');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Children''s Educational Puzzle', 'Fun and educational puzzle designed to challenge young minds. Perfect for ages 3-6.', '2023-09-29', 24.99, 'PerryLee');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Luxury Yoga Mat', 'Experience comfort and style during your workouts with this premium yoga mat. Eco-friendly materials included.', '2023-10-01', 69.99, 'dollheartz');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Photography Tripod', 'Sturdy and stable tripod suitable for both photography and videography. Compact design for easy transport.', '2023-08-20', 45.00, 'FrostyBite');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Wireless Bluetooth Speaker', 'Enjoy high-quality sound anywhere you go with this portable Bluetooth speaker. Waterproof and durable.', '2023-09-20', 79.99, 'karen_poor_reviews');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Smart Home Hub', 'Control all your smart devices from a single hub. Compatible with various brands for ultimate convenience.', '2023-09-10', 199.99, 'BillyGarcia');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Stylish Laptop Sleeve', 'Protect your laptop with this fashionable and durable sleeve. Fits most devices comfortably.', '2023-09-15', 39.99, 'nthPerson');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Luxury Handbag', 'Elegant handbag made from premium materials, perfect for any occasion. A must-have for fashion lovers.', '2023-10-02', 249.99, 'admin');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Indoor Plant Care Kit', 'Everything you need to keep your houseplants healthy and happy. Includes soil, nutrients, and tools.', '2023-08-25', 29.99, 'd_trump');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Portable Power Bank', 'Never run out of battery on the go with this high-capacity portable power bank. Charges multiple devices.', '2023-09-18', 39.99, 'RobertSlay');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Portable Blender', 'Compact and efficient blender for smoothies on the go. Perfect for busy individuals.', '2023-09-15', 45.99, 'FrostyBite');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Gaming Mouse', 'High precision gaming mouse with customizable RGB lighting. Ideal for competitive gamers.', '2023-08-22', 79.99, 'BillyGarcia');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Camping Chair', 'Lightweight folding chair perfect for camping trips and outdoor events.', '2023-09-10', 34.50, 'ChristineNguyen');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Wireless Earbuds', 'Seamless connectivity and great sound quality for music lovers. Comes with a charging case.', '2023-07-30', 89.99, 'elon_musk');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Yoga Mat', 'Eco-friendly yoga mat, non-slip and durable for all your exercise needs.', '2023-09-05', 29.99, 'd_trump');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Art Supplies Set', 'Complete set for budding artists including paints, brushes, and canvases.', '2023-08-15', 59.99, 'Gigi');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Smart Garden Kit', 'Automated indoor garden kit for growing herbs and vegetables year-round.', '2023-09-01', 199.99, 'PerryLee');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Electric Guitar', 'Beginner-friendly electric guitar with accessories included for new musicians.', '2023-08-25', 299.99, 'dollheartz');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Luxury Throw Blanket', 'Soft and cozy throw blanket made from high-quality materials. Perfect for any living space.', '2023-09-12', 79.00, 'nthPerson');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Fitness Tracker', 'Monitor your health and fitness goals with this sleek and stylish fitness tracker.', '2023-08-30', 69.99, 'RobertSlay');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Wooden Puzzle', 'Handcrafted wooden puzzle that enhances cognitive skills for children aged 3-7.', '2023-09-08', 24.99, 'karen_poor_reviews');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Compact 3D Printer', 'A compact 3D printer perfect for beginners, featuring easy setup and high-resolution printing.', '2023-09-20', 299.99, 'FrostyBite');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Children''s Art Supplies Set', 'A diverse set of art supplies designed for kids to unleash their creativity, including crayons, markers, and papers.', '2023-08-15', 45.00, 'karen_poor_reviews');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Outdoor Adventure Tent', 'A lightweight, easy-to-set-up tent perfect for camping enthusiasts, designed to withstand various weather conditions.', '2023-07-30', 199.95, 'PerryLee');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Wireless Gaming Router', 'Enhance your online gaming experience with this high-speed wireless router, featuring low latency and extended range.', '2023-08-25', 129.99, 'BillyGarcia');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Vintage-Inspired Jewelry Box', 'An elegant jewelry box made of wood with intricate carvings, perfect for storing your treasured accessories.', '2023-09-05', 75.50, 'Gigi');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Camping Cooking Set', 'All-in-one cooking set for outdoor adventures, including pots, pans, and utensils, lightweight and durable.', '2023-08-10', 89.99, 'ChristineNguyen');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Portable Bluetooth Projector', 'Enjoy movies and presentations on the go with this compact Bluetooth projector, compatible with multiple devices.', '2023-09-12', 349.00, 'elon_musk');
# INSERT INTO railway.item (`title`, `description`, `date_posted`, `price`, `posted_by`) VALUES ('Educational STEM Toy Set', 'An engaging STEM toy set that promotes learning through fun experiments and building projects for kids.', '2023-09-15', 59.99, 'd_trump');
# COMMIT;

# %% [markdown]
# ##### Build SQL to map categories in `item_category`

# %%
# Copy the output into MySQL Workbench and run after inserting items.
def sql_quote(s: str) -> str:
    if s is None:
        return "NULL"
    s = str(s).replace("\\", "\\\\").replace("'", "''").replace("\n", " ")
    return f"'{s}'"

lines = []
lines.append("-- Map items to categories (uses title + posted_by to find item_id)")
lines.append("START TRANSACTION;")
for it in generated_items:
    title = sql_quote(it["title"])
    posted_by = sql_quote(it["posted_by"])
    for cat in it["categories"]:
        cat_q = sql_quote(cat)
        # Use INSERT IGNORE to avoid duplicate PK (item_id, category_name)
        lines.append(
            "INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)\n"
            # "INSERT IGNORE INTO comp440db.item_category (`item_id`, `category_name`)\n"
            f"SELECT i.id, {cat_q} FROM `item` AS i\n"
            f"WHERE i.title = {title} AND i.posted_by = {posted_by}\n"
            "ORDER BY i.id DESC\n"
            "LIMIT 1;"
        )
lines.append("COMMIT;")

sql_insert_item_categories = "\n".join(lines)
print(sql_insert_item_categories)
# Out:
# -- Map items to categories (uses title + posted_by to find item_id)
# START TRANSACTION;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'cameras' FROM `item` AS i
# WHERE i.title = 'Vintage Camera' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'collectibles' FROM `item` AS i
# WHERE i.title = 'Vintage Camera' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'bikes' FROM `item` AS i
# WHERE i.title = 'Mountain Bike' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'outdoor activities' FROM `item` AS i
# WHERE i.title = 'Mountain Bike' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Wireless Headphones' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'headphones' FROM `item` AS i
# WHERE i.title = 'Wireless Headphones' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'furniture' FROM `item` AS i
# WHERE i.title = 'Gaming Chair' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'baby' FROM `item` AS i
# WHERE i.title = 'Baby Stroller' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'strollers' FROM `item` AS i
# WHERE i.title = 'Baby Stroller' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'smart watches' FROM `item` AS i
# WHERE i.title = 'Smart Watch' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'technology' FROM `item` AS i
# WHERE i.title = 'Smart Watch' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'fitness' FROM `item` AS i
# WHERE i.title = 'Fitness Tracker' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Fitness Tracker' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'board games' FROM `item` AS i
# WHERE i.title = 'Board Game Set' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'entertainment' FROM `item` AS i
# WHERE i.title = 'Board Game Set' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'books' FROM `item` AS i
# WHERE i.title = 'Children''s Books' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'educational toys' FROM `item` AS i
# WHERE i.title = 'Children''s Books' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'musical instruments' FROM `item` AS i
# WHERE i.title = 'Electric Guitar' AND i.posted_by = 'admin'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'entertainment' FROM `item` AS i
# WHERE i.title = 'Electric Guitar' AND i.posted_by = 'admin'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'pet supplies' FROM `item` AS i
# WHERE i.title = 'Pet Supplies Bundle' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'animals' FROM `item` AS i
# WHERE i.title = 'Pet Supplies Bundle' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Wireless Earbuds' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'accessories' FROM `item` AS i
# WHERE i.title = 'Wireless Earbuds' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'camping & hiking' FROM `item` AS i
# WHERE i.title = 'Camping Tent' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'outdoors' FROM `item` AS i
# WHERE i.title = 'Camping Tent' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'arts' FROM `item` AS i
# WHERE i.title = 'Art Supplies Kit' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'crafts' FROM `item` AS i
# WHERE i.title = 'Art Supplies Kit' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'cellphone' FROM `item` AS i
# WHERE i.title = 'Smartphone Stand' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'accessories' FROM `item` AS i
# WHERE i.title = 'Smartphone Stand' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'kitchen' FROM `item` AS i
# WHERE i.title = 'Electric Kettle' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'home improvement' FROM `item` AS i
# WHERE i.title = 'Electric Kettle' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'fitness' FROM `item` AS i
# WHERE i.title = 'Yoga Mat' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'gym wear' FROM `item` AS i
# WHERE i.title = 'Yoga Mat' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'lighting' FROM `item` AS i
# WHERE i.title = 'LED Desk Lamp' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'office supplies' FROM `item` AS i
# WHERE i.title = 'LED Desk Lamp' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'games' FROM `item` AS i
# WHERE i.title = 'Puzzle Game' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'toys' FROM `item` AS i
# WHERE i.title = 'Puzzle Game' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'garden' FROM `item` AS i
# WHERE i.title = 'Garden Tools Set' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'tools' FROM `item` AS i
# WHERE i.title = 'Garden Tools Set' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'luxury items' FROM `item` AS i
# WHERE i.title = 'Luxury Watch' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'watches' FROM `item` AS i
# WHERE i.title = 'Luxury Watch' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'drones' FROM `item` AS i
# WHERE i.title = 'Drone with Camera' AND i.posted_by = 'admin'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'technology' FROM `item` AS i
# WHERE i.title = 'Drone with Camera' AND i.posted_by = 'admin'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'educational toys' FROM `item` AS i
# WHERE i.title = 'Children''s Educational Toys' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'toys' FROM `item` AS i
# WHERE i.title = 'Children''s Educational Toys' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, '3d printers' FROM `item` AS i
# WHERE i.title = 'Portable 3D Printer' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Portable 3D Printer' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'accessories' FROM `item` AS i
# WHERE i.title = 'Stylish Laptop Backpack' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'clothing' FROM `item` AS i
# WHERE i.title = 'Stylish Laptop Backpack' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Wireless Bluetooth Speaker' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'music' FROM `item` AS i
# WHERE i.title = 'Wireless Bluetooth Speaker' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'furniture' FROM `item` AS i
# WHERE i.title = 'Garden Patio Set' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'outdoors' FROM `item` AS i
# WHERE i.title = 'Garden Patio Set' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'camping & hiking' FROM `item` AS i
# WHERE i.title = 'Camping Hammock' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'outdoors' FROM `item` AS i
# WHERE i.title = 'Camping Hammock' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'toys' FROM `item` AS i
# WHERE i.title = 'Kids'' Educational Puzzle' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'educational toys' FROM `item` AS i
# WHERE i.title = 'Kids'' Educational Puzzle' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'kitchen' FROM `item` AS i
# WHERE i.title = 'Coffee Maker with Grinder' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'home' FROM `item` AS i
# WHERE i.title = 'Coffee Maker with Grinder' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'crafts' FROM `item` AS i
# WHERE i.title = 'Crafting Supplies Bundle' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'diy' FROM `item` AS i
# WHERE i.title = 'Crafting Supplies Bundle' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'accessories' FROM `item` AS i
# WHERE i.title = 'Smartphone Tripod' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'beauty' FROM `item` AS i
# WHERE i.title = 'Luxury Skincare Set' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'personal care' FROM `item` AS i
# WHERE i.title = 'Luxury Skincare Set' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'drones' FROM `item` AS i
# WHERE i.title = 'High-Performance Drone' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'High-Performance Drone' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'collectibles' FROM `item` AS i
# WHERE i.title = 'Vintage Vinyl Records Collection' AND i.posted_by = 'admin'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'music' FROM `item` AS i
# WHERE i.title = 'Vintage Vinyl Records Collection' AND i.posted_by = 'admin'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'cell phones' FROM `item` AS i
# WHERE i.title = 'Portable Phone Charger' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'accessories' FROM `item` AS i
# WHERE i.title = 'Portable Phone Charger' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'camping & hiking' FROM `item` AS i
# WHERE i.title = 'Camping Lantern' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'outdoors' FROM `item` AS i
# WHERE i.title = 'Camping Lantern' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'arts' FROM `item` AS i
# WHERE i.title = 'Kids'' Art Supplies' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'toys' FROM `item` AS i
# WHERE i.title = 'Kids'' Art Supplies' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Wireless Gaming Mouse' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'music' FROM `item` AS i
# WHERE i.title = 'Vintage Vinyl Record Player' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'collectibles' FROM `item` AS i
# WHERE i.title = 'Vintage Vinyl Record Player' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'luxury items' FROM `item` AS i
# WHERE i.title = 'Luxury Leather Wallet' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'accessories' FROM `item` AS i
# WHERE i.title = 'Luxury Leather Wallet' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'cameras' FROM `item` AS i
# WHERE i.title = 'Smartphone Camera Lens Kit' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'accessories' FROM `item` AS i
# WHERE i.title = 'Smartphone Camera Lens Kit' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'outdoor activities' FROM `item` AS i
# WHERE i.title = 'Outdoor Adventure Backpack' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Bluetooth Wireless Earphones' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'accessories' FROM `item` AS i
# WHERE i.title = 'Bluetooth Wireless Earphones' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'garden' FROM `item` AS i
# WHERE i.title = 'Garden Composter Bin' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'home improvement' FROM `item` AS i
# WHERE i.title = 'Garden Composter Bin' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'kitchen' FROM `item` AS i
# WHERE i.title = 'Electric Pressure Cooker' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Electric Pressure Cooker' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'books' FROM `item` AS i
# WHERE i.title = 'Adult Coloring Book' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'arts' FROM `item` AS i
# WHERE i.title = 'Adult Coloring Book' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, '3d printers' FROM `item` AS i
# WHERE i.title = '3D Printer PLA Filament' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'accessories' FROM `item` AS i
# WHERE i.title = '3D Printer PLA Filament' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'camping & hiking' FROM `item` AS i
# WHERE i.title = 'Camping Backpack 50L' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'outdoors' FROM `item` AS i
# WHERE i.title = 'Camping Backpack 50L' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Wireless Gaming Headset' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'scooters' FROM `item` AS i
# WHERE i.title = 'Electric Scooter' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'vehicles' FROM `item` AS i
# WHERE i.title = 'Electric Scooter' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Portable Projector' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'entertainment' FROM `item` AS i
# WHERE i.title = 'Portable Projector' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'sports' FROM `item` AS i
# WHERE i.title = 'Stainless Steel Water Bottle' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'outdoors' FROM `item` AS i
# WHERE i.title = 'Stainless Steel Water Bottle' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'toys' FROM `item` AS i
# WHERE i.title = 'Kids Educational Puzzle' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'educational toys' FROM `item` AS i
# WHERE i.title = 'Kids Educational Puzzle' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'accessories' FROM `item` AS i
# WHERE i.title = 'Luxury Leather Backpack' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Bluetooth Soundbar' AND i.posted_by = 'admin'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'home' FROM `item` AS i
# WHERE i.title = 'Bluetooth Soundbar' AND i.posted_by = 'admin'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'fitness' FROM `item` AS i
# WHERE i.title = 'Fitness Resistance Bands' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'sports' FROM `item` AS i
# WHERE i.title = 'Fitness Resistance Bands' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'smart home' FROM `item` AS i
# WHERE i.title = 'Smart Home Security Camera' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'security systems' FROM `item` AS i
# WHERE i.title = 'Smart Home Security Camera' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'jewelry' FROM `item` AS i
# WHERE i.title = 'Artisan Handmade Jewelry' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'handmade' FROM `item` AS i
# WHERE i.title = 'Artisan Handmade Jewelry' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Wireless Car Charger' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'accessories' FROM `item` AS i
# WHERE i.title = 'Wireless Car Charger' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Portable Bluetooth Speaker' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'music' FROM `item` AS i
# WHERE i.title = 'Portable Bluetooth Speaker' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'toys' FROM `item` AS i
# WHERE i.title = 'Kids'' Puzzle Set' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'educational toys' FROM `item` AS i
# WHERE i.title = 'Kids'' Puzzle Set' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'furniture' FROM `item` AS i
# WHERE i.title = 'Ergonomic Office Chair' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'office supplies' FROM `item` AS i
# WHERE i.title = 'Ergonomic Office Chair' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'beauty' FROM `item` AS i
# WHERE i.title = 'Luxury Skincare Set' AND i.posted_by = 'bellaffelipe'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'personal care' FROM `item` AS i
# WHERE i.title = 'Luxury Skincare Set' AND i.posted_by = 'bellaffelipe'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, '3d printers' FROM `item` AS i
# WHERE i.title = '3D Printing Filament' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'crafts' FROM `item` AS i
# WHERE i.title = '3D Printing Filament' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Smartphone Gimbal Stabilizer' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'mobile' FROM `item` AS i
# WHERE i.title = 'Smartphone Gimbal Stabilizer' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'clothing' FROM `item` AS i
# WHERE i.title = 'Leather Backpack' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'travel' FROM `item` AS i
# WHERE i.title = 'Leather Backpack' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'bikes' FROM `item` AS i
# WHERE i.title = 'Bicycle Repair Kit' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'tools' FROM `item` AS i
# WHERE i.title = 'Bicycle Repair Kit' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'board games' FROM `item` AS i
# WHERE i.title = 'Educational Board Game' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'accessories' FROM `item` AS i
# WHERE i.title = 'Gaming Mouse Pad' AND i.posted_by = 'admin'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'cameras' FROM `item` AS i
# WHERE i.title = 'High-Resolution Camera' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'High-Resolution Camera' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'camping & hiking' FROM `item` AS i
# WHERE i.title = 'Camping Cooking Set' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'kitchen' FROM `item` AS i
# WHERE i.title = 'Camping Cooking Set' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'toys' FROM `item` AS i
# WHERE i.title = 'Children''s Educational Puzzle' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'educational toys' FROM `item` AS i
# WHERE i.title = 'Children''s Educational Puzzle' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'fitness' FROM `item` AS i
# WHERE i.title = 'Luxury Yoga Mat' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'gym wear' FROM `item` AS i
# WHERE i.title = 'Luxury Yoga Mat' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'accessories' FROM `item` AS i
# WHERE i.title = 'Photography Tripod' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'cameras' FROM `item` AS i
# WHERE i.title = 'Photography Tripod' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Wireless Bluetooth Speaker' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'music' FROM `item` AS i
# WHERE i.title = 'Wireless Bluetooth Speaker' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'smart home' FROM `item` AS i
# WHERE i.title = 'Smart Home Hub' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'technology' FROM `item` AS i
# WHERE i.title = 'Smart Home Hub' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'accessories' FROM `item` AS i
# WHERE i.title = 'Stylish Laptop Sleeve' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'computers' FROM `item` AS i
# WHERE i.title = 'Stylish Laptop Sleeve' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'luxury items' FROM `item` AS i
# WHERE i.title = 'Luxury Handbag' AND i.posted_by = 'admin'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'clothing' FROM `item` AS i
# WHERE i.title = 'Luxury Handbag' AND i.posted_by = 'admin'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'garden' FROM `item` AS i
# WHERE i.title = 'Indoor Plant Care Kit' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'home' FROM `item` AS i
# WHERE i.title = 'Indoor Plant Care Kit' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Portable Power Bank' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'mobile' FROM `item` AS i
# WHERE i.title = 'Portable Power Bank' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'kitchen' FROM `item` AS i
# WHERE i.title = 'Portable Blender' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'fitness' FROM `item` AS i
# WHERE i.title = 'Portable Blender' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Gaming Mouse' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'outdoor activities' FROM `item` AS i
# WHERE i.title = 'Camping Chair' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'camping & hiking' FROM `item` AS i
# WHERE i.title = 'Camping Chair' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Wireless Earbuds' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'accessories' FROM `item` AS i
# WHERE i.title = 'Wireless Earbuds' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'fitness' FROM `item` AS i
# WHERE i.title = 'Yoga Mat' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'personal care' FROM `item` AS i
# WHERE i.title = 'Yoga Mat' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'arts' FROM `item` AS i
# WHERE i.title = 'Art Supplies Set' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'crafts' FROM `item` AS i
# WHERE i.title = 'Art Supplies Set' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'garden' FROM `item` AS i
# WHERE i.title = 'Smart Garden Kit' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'technology' FROM `item` AS i
# WHERE i.title = 'Smart Garden Kit' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'musical instruments' FROM `item` AS i
# WHERE i.title = 'Electric Guitar' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'entertainment' FROM `item` AS i
# WHERE i.title = 'Electric Guitar' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'home' FROM `item` AS i
# WHERE i.title = 'Luxury Throw Blanket' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'bedding' FROM `item` AS i
# WHERE i.title = 'Luxury Throw Blanket' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'fitness' FROM `item` AS i
# WHERE i.title = 'Fitness Tracker' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'technology' FROM `item` AS i
# WHERE i.title = 'Fitness Tracker' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'toys' FROM `item` AS i
# WHERE i.title = 'Wooden Puzzle' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'educational toys' FROM `item` AS i
# WHERE i.title = 'Wooden Puzzle' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, '3d printers' FROM `item` AS i
# WHERE i.title = 'Compact 3D Printer' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Compact 3D Printer' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'arts' FROM `item` AS i
# WHERE i.title = 'Children''s Art Supplies Set' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'toys' FROM `item` AS i
# WHERE i.title = 'Children''s Art Supplies Set' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'camping & hiking' FROM `item` AS i
# WHERE i.title = 'Outdoor Adventure Tent' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'outdoors' FROM `item` AS i
# WHERE i.title = 'Outdoor Adventure Tent' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'technology' FROM `item` AS i
# WHERE i.title = 'Wireless Gaming Router' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Wireless Gaming Router' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'jewelry' FROM `item` AS i
# WHERE i.title = 'Vintage-Inspired Jewelry Box' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'collectibles' FROM `item` AS i
# WHERE i.title = 'Vintage-Inspired Jewelry Box' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'camping & hiking' FROM `item` AS i
# WHERE i.title = 'Camping Cooking Set' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'kitchen' FROM `item` AS i
# WHERE i.title = 'Camping Cooking Set' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'electronics' FROM `item` AS i
# WHERE i.title = 'Portable Bluetooth Projector' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'entertainment' FROM `item` AS i
# WHERE i.title = 'Portable Bluetooth Projector' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'educational toys' FROM `item` AS i
# WHERE i.title = 'Educational STEM Toy Set' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.item_category (`item_id`, `category_name`)
# SELECT i.id, 'toys' FROM `item` AS i
# WHERE i.title = 'Educational STEM Toy Set' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# COMMIT;

# %% [markdown]
# ##### Generate sample reviews for each generated item

# %%
# Dependencies: random, datetime, openai (already installed earlier)
import os
import json
import random
import time
from datetime import date, datetime, timedelta

ALLOWED_SCORES = ["Excellent", "Good", "Fair", "Poor"]

def pick_score():
    # Weighted distribution: more positive than negative
    return random.choices(
        population=ALLOWED_SCORES,
        weights=[45, 30, 18, 7],
        k=1
    )[0]

def clamp_date(dmin: date, dmax: date) -> date:
    if dmin > dmax:
        return dmax
    return dmin

def random_date_between(dmin_iso: str, dmax: date | None = None) -> str:
    # dmin_iso is 'YYYY-MM-DD'; dmax defaults to today
    dmax = dmax or date.today()
    try:
        y, m, d = map(int, dmin_iso.split("-"))
        start = date(y, m, d)
    except Exception:
        start = date.today() - timedelta(days=90)
    start = clamp_date(start, dmax)
    days = (dmax - start).days
    r = start + timedelta(days=random.randint(0, max(0, days)))
    return r.isoformat()

def default_remark_for_score(score: str, title: str) -> str:
    # Fallback if LLM output cannot be parsed
    templates = {
        "Excellent": f"Absolutely love the {title}! Great quality and exceeded expectations.",
        "Good": f"The {title} works well and is a solid value. Satisfied with the purchase.",
        "Fair": f"The {title} is okay but has a few drawbacks. Gets the job done.",
        "Poor": f"Not happy with the {title}. Quality and performance were disappointing."
    }
    return templates.get(score, f"The {title} was acceptable overall.")

def generate_reviews_with_llm(generated_items, usernames, max_per_item=3, batch_size=10, retry_max=3, base_sleep=0.4):
    # Build planned reviews (choose reviewers and scores first)
    planned = []
    usernames_set = set(usernames)

    for item in generated_items:
        seller = item["posted_by"]
        candidates = [u for u in usernames if u != seller]
        if not candidates:
            continue
        count = random.randint(1, max_per_item)
        chosen_reviewers = random.sample(candidates, k=min(count, len(candidates)))
        for reviewer in chosen_reviewers:
            score = pick_score()
            # Review date on/after item.date_posted up to today
            review_date = random_date_between(item["date_posted"])
            planned.append({
                "item_title": item["title"],
                "item_posted_by": seller,
                "item_description": item.get("description", ""),
                "user_id": reviewer,
                "score": score,
                "review_date": review_date,
                "remark": None  # to be filled by LLM
            })

    if not planned:
        print("No planned reviews (not enough distinct users).")
        return []

    # Helper to request remarks with retry/backoff
    def request_remarks(entries):
        system_msg = (
            "You are a helpful assistant that writes short review remarks. "
            "Return ONLY compact JSON and nothing else."
        )
        user_req = {
            "instructions": [
                "For each entry, write a 1-2 sentence remark that matches the sentiment of its score:",
                "- Excellent: clearly positive",
                "- Good: positive with minor caveat at most",
                "- Fair: mixed/neutral with some critique",
                "- Poor: clearly negative",
                "Keep remarks realistic and concise. No emojis. No markdown."
            ],
            "return_shape": {
                "remarks": ["string, same order and length as entries"]
            },
            "entries": [
                {
                    "score": r["score"],
                    "title": r["item_title"],
                    "context": (r["item_description"][:180] if r.get("item_description") else "")
                } for r in entries
            ]
        }
        for attempt in range(retry_max):
            try:
                resp = client.chat.completions.create(
                    model="gpt-4o-mini",
                    temperature=0.6,
                    messages=[
                        {"role": "system", "content": system_msg},
                        {"role": "user", "content": "Write remarks for these entries. Output strictly JSON."},
                        {"role": "user", "content": json.dumps(user_req)}
                    ]
                )
                content = resp.choices[0].message.content.strip()
                data = json.loads(content)
                return data.get("remarks", [])
            except Exception:
                # Exponential backoff with jitter
                sleep_s = (base_sleep * (2 ** attempt)) + random.uniform(0, 0.25)
                time.sleep(sleep_s)
        return []

    # Use batches of review entries (not items). batch_size=5 => 5 remarks per call.
    out_reviews = []
    for i in range(0, len(planned), batch_size):
        batch = planned[i:i+batch_size]
        remarks = request_remarks(batch)

        # Merge remarks with batch, applying safe fallbacks
        for idx, review in enumerate(batch):
            title = review["item_title"]
            score = review["score"]
            remark = None
            if idx < len(remarks) and isinstance(remarks[idx], str):
                remark = remarks[idx].strip()
            if not remark:
                remark = default_remark_for_score(score, title)

            # Validate fields
            if review["score"] not in ALLOWED_SCORES:
                continue
            if review["user_id"] == review["item_posted_by"]:
                continue
            if review["user_id"] not in usernames_set:
                continue
            # Finalize
            out_reviews.append({
                "item_title": review["item_title"],
                "item_posted_by": review["item_posted_by"],
                "user_id": review["user_id"],
                "score": review["score"],
                "review_date": review["review_date"],  # YYYY-MM-DD
                "remark": remark
            })

        # Gentle pacing between calls
        time.sleep(0.15)

    # Enforce one-review-per-user-per-item locally (mirror DB unique constraint)
    seen = set()
    deduped = []
    for r in out_reviews:
        key = (r["user_id"], r["item_title"], r["item_posted_by"])
        if key in seen:
            continue
        seen.add(key)
        deduped.append(r)

    print(f"Prepared {len(deduped)} reviews for {len(generated_items)} items.")
    # Preview first few
    for k, r in enumerate(deduped[:5], 1):
        print(k, {**r, "remark": (r["remark"][:80] + "..." if len(r["remark"]) > 80 else r["remark"])})
    return deduped

generated_reviews = generate_reviews_with_llm(generated_items, usernames, max_per_item=3)
# Out:
# Prepared 196 reviews for 100 items.
# 1 {'item_title': 'Vintage Camera', 'item_posted_by': 'ChristineNguyen', 'user_id': 'nthPerson', 'score': 'Excellent', 'review_date': '2023-12-01', 'remark': 'An outstanding choice for photography enthusiasts, this vintage camera is in exc...'}
# 2 {'item_title': 'Vintage Camera', 'item_posted_by': 'ChristineNguyen', 'user_id': 'Gigi', 'score': 'Good', 'review_date': '2025-01-02', 'remark': 'A solid option for photography lovers, this vintage camera is in great shape, th...'}
# 3 {'item_title': 'Mountain Bike', 'item_posted_by': 'BillyGarcia', 'user_id': 'nthPerson', 'score': 'Excellent', 'review_date': '2024-09-10', 'remark': 'This mountain bike is exceptional, offering high performance and light use, maki...'}
# 4 {'item_title': 'Mountain Bike', 'item_posted_by': 'BillyGarcia', 'user_id': 'Gigi', 'score': 'Excellent', 'review_date': '2023-11-29', 'remark': 'An impressive high-performance mountain bike that is lightly used, ideal for any...'}
# 5 {'item_title': 'Wireless Headphones', 'item_posted_by': 'FrostyBite', 'user_id': 'PerryLee', 'score': 'Excellent', 'review_date': '2023-10-11', 'remark': 'These wireless headphones provide excellent sound quality and comfort, perfect f...'}

# %% [markdown]
# #### Build SQL to insert generated reviews into `comp440db.review`

# %%
# Copy the output into MySQL Workbench and run AFTER inserting items.
from decimal import Decimal

def sql_quote(s: str) -> str:
    if s is None:
        return "NULL"
    s = str(s).replace("\\", "\\\\").replace("'", "''").replace("\n", " ")
    return f"'{s}'"

lines = []
lines.append("-- Insert generated reviews (resolve item_id by title + posted_by)")
lines.append("START TRANSACTION;")
for rv in generated_reviews:
    review_date = sql_quote(rv["review_date"])  # 'YYYY-MM-DD'
    score = sql_quote(rv["score"])              # Enum: Excellent/Good/Fair/Poor
    remark = sql_quote(rv["remark"])
    user_id = sql_quote(rv["user_id"])
    title_q = sql_quote(rv["item_title"])
    posted_by_q = sql_quote(rv["item_posted_by"])

    # Use INSERT IGNORE to avoid violating unique constraint (user_id, item_id) on reruns
    lines.append(
        "INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)\n"
        # "INSERT IGNORE INTO comp440db.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)\n"
        f"SELECT {review_date}, {score}, {remark}, {user_id}, i.id FROM railway.item AS i\n"
        # f"SELECT {review_date}, {score}, {remark}, {user_id}, i.id FROM comp440db.item AS i\n"
        f"WHERE i.title = {title_q} AND i.posted_by = {posted_by_q}\n"
        "ORDER BY i.id DESC\n"
        "LIMIT 1;"
    )
lines.append("COMMIT;")

sql_insert_reviews = "\n".join(lines)
print(sql_insert_reviews)
# Out:
# -- Insert generated reviews (resolve item_id by title + posted_by)
# START TRANSACTION;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-12-01', 'Excellent', 'An outstanding choice for photography enthusiasts, this vintage camera is in excellent condition and ready for great shots.', 'nthPerson', i.id FROM railway.item AS i
# WHERE i.title = 'Vintage Camera' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-01-02', 'Good', 'A solid option for photography lovers, this vintage camera is in great shape, though there may be minor considerations for some users.', 'Gigi', i.id FROM railway.item AS i
# WHERE i.title = 'Vintage Camera' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-09-10', 'Excellent', 'This mountain bike is exceptional, offering high performance and light use, making it perfect for adventurous terrains.', 'nthPerson', i.id FROM railway.item AS i
# WHERE i.title = 'Mountain Bike' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-11-29', 'Excellent', 'An impressive high-performance mountain bike that is lightly used, ideal for anyone looking to tackle rugged trails.', 'Gigi', i.id FROM railway.item AS i
# WHERE i.title = 'Mountain Bike' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-10-11', 'Excellent', 'These wireless headphones provide excellent sound quality and comfort, perfect for music lovers seeking a great listening experience.', 'PerryLee', i.id FROM railway.item AS i
# WHERE i.title = 'Wireless Headphones' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-10-20', 'Poor', 'This gaming chair falls short of expectations, as it struggles to deliver on comfort despite its ergonomic design.', 'Gigi', i.id FROM railway.item AS i
# WHERE i.title = 'Gaming Chair' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-11-08', 'Good', 'A practical choice for parents on the go, this baby stroller is lightweight and in great condition, making travel with your child easier.', 'BillyGarcia', i.id FROM railway.item AS i
# WHERE i.title = 'Baby Stroller' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-08-06', 'Excellent', 'This smartwatch is a fantastic find, packed with features and in like-new condition, perfect for anyone wanting to stay connected.', 'Gigi', i.id FROM railway.item AS i
# WHERE i.title = 'Smart Watch' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-11-13', 'Fair', 'While the smartwatch offers great features and is in excellent condition, some may find it lacks in certain areas compared to competitors.', 'nthPerson', i.id FROM railway.item AS i
# WHERE i.title = 'Smart Watch' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-12-15', 'Excellent', 'An excellent fitness tracker that is water-resistant and packed with useful features, ideal for anyone serious about their fitness journey.', 'elon_musk', i.id FROM railway.item AS i
# WHERE i.title = 'Fitness Tracker' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-12-04', 'Good', 'A solid choice for fitness enthusiasts, this tracker offers essential features and durability.', 'ChristineNguyen', i.id FROM railway.item AS i
# WHERE i.title = 'Fitness Tracker' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-06-25', 'Good', 'A solid choice for fitness enthusiasts, this tracker offers essential features and durability.', 'bellaffelipe', i.id FROM railway.item AS i
# WHERE i.title = 'Fitness Tracker' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-02-24', 'Excellent', 'An outstanding board game set that promises endless fun for family gatherings and game nights.', 'admin', i.id FROM railway.item AS i
# WHERE i.title = 'Board Game Set' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-03-19', 'Good', 'A nice collection of children''s books, though some may show signs of wear from previous use.', 'dollheartz', i.id FROM railway.item AS i
# WHERE i.title = 'Children''s Books' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-06-20', 'Excellent', 'An outstanding collection of children''s books that will delight young readers.', 'BillyGarcia', i.id FROM railway.item AS i
# WHERE i.title = 'Children''s Books' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-07-31', 'Excellent', 'An outstanding collection of children''s books that will delight young readers.', 'admin', i.id FROM railway.item AS i
# WHERE i.title = 'Children''s Books' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-04-20', 'Fair', 'While this electric guitar is beginner-friendly, it may lack the quality needed for more advanced players.', 'Gigi', i.id FROM railway.item AS i
# WHERE i.title = 'Electric Guitar' AND i.posted_by = 'admin'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-03-26', 'Excellent', 'An excellent bundle of pet supplies that provides great value for pet owners.', 'FrostyBite', i.id FROM railway.item AS i
# WHERE i.title = 'Pet Supplies Bundle' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-04-23', 'Good', 'A good deal on a pet supplies bundle, offering a variety of essentials for furry friends.', 'admin', i.id FROM railway.item AS i
# WHERE i.title = 'Pet Supplies Bundle' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-11-06', 'Good', 'These wireless earbuds deliver impressive sound quality, making them a great choice for music lovers on the go.', 'd_trump', i.id FROM railway.item AS i
# WHERE i.title = 'Wireless Earbuds' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-03-05', 'Poor', 'The camping tent does not meet expectations in terms of quality and usability.', 'RobertSlay', i.id FROM railway.item AS i
# WHERE i.title = 'Camping Tent' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-07-02', 'Excellent', 'This art supplies kit is an outstanding choice for anyone looking to explore their creativity.', 'FrostyBite', i.id FROM railway.item AS i
# WHERE i.title = 'Art Supplies Kit' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-11-25', 'Good', 'The smartphone stand is functional and portable, making it a solid option for everyday use.', 'Gigi', i.id FROM railway.item AS i
# WHERE i.title = 'Smartphone Stand' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-10-26', 'Good', 'The smartphone stand is functional and portable, making it a solid option for everyday use.', 'techy', i.id FROM railway.item AS i
# WHERE i.title = 'Smartphone Stand' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-10-21', 'Good', 'The electric kettle performs well and is energy-efficient, though there are some minor drawbacks.', 'd_trump', i.id FROM railway.item AS i
# WHERE i.title = 'Electric Kettle' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-11-24', 'Fair', 'While the electric kettle boils water quickly, it lacks some features that could enhance its usability.', 'RobertSlay', i.id FROM railway.item AS i
# WHERE i.title = 'Electric Kettle' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-01-21', 'Poor', 'The yoga mat fails to provide adequate support and may not be suitable for serious workouts.', 'techy', i.id FROM railway.item AS i
# WHERE i.title = 'Yoga Mat' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-09-23', 'Good', 'This yoga mat offers great cushioning and is easy to transport, making it a reliable choice.', 'Gigi', i.id FROM railway.item AS i
# WHERE i.title = 'Yoga Mat' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-07-14', 'Good', 'This yoga mat offers great cushioning and is easy to transport, making it a reliable choice.', 'bellaffelipe', i.id FROM railway.item AS i
# WHERE i.title = 'Yoga Mat' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-04-01', 'Excellent', 'The LED desk lamp is a fantastic addition to any workspace with its stylish design and adjustable features.', 'dollheartz', i.id FROM railway.item AS i
# WHERE i.title = 'LED Desk Lamp' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-03-07', 'Excellent', 'An excellent choice for family game nights, offering engaging gameplay and vibrant themes.', 'admin', i.id FROM railway.item AS i
# WHERE i.title = 'Puzzle Game' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-01-26', 'Fair', 'While the game is engaging, it may not hold everyone''s interest for long.', 'ChristineNguyen', i.id FROM railway.item AS i
# WHERE i.title = 'Puzzle Game' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-12-24', 'Poor', 'The game fails to deliver on its promise of engagement despite its colorful pieces.', 'PerryLee', i.id FROM railway.item AS i
# WHERE i.title = 'Puzzle Game' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-02-25', 'Excellent', 'This garden tools set is a fantastic all-in-one solution for anyone looking to simplify their gardening tasks.', 'd_trump', i.id FROM railway.item AS i
# WHERE i.title = 'Garden Tools Set' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-09-21', 'Poor', 'Unfortunately, this garden tools set lacks durability and effectiveness in practical use.', 'karen_poor_reviews', i.id FROM railway.item AS i
# WHERE i.title = 'Garden Tools Set' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-12-14', 'Fair', 'The watch is elegant and versatile, but its performance may not meet all expectations.', 'd_trump', i.id FROM railway.item AS i
# WHERE i.title = 'Luxury Watch' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-06-05', 'Good', 'This drone impresses with its camera quality, making it a great investment for aerial photography enthusiasts.', 'ChristineNguyen', i.id FROM railway.item AS i
# WHERE i.title = 'Drone with Camera' AND i.posted_by = 'admin'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-05-13', 'Good', 'This drone impresses with its camera quality, making it a great investment for aerial photography enthusiasts.', 'Gigi', i.id FROM railway.item AS i
# WHERE i.title = 'Drone with Camera' AND i.posted_by = 'admin'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-03-19', 'Good', 'This drone impresses with its camera quality, making it a great investment for aerial photography enthusiasts.', 'BillyGarcia', i.id FROM railway.item AS i
# WHERE i.title = 'Drone with Camera' AND i.posted_by = 'admin'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-02-05', 'Good', 'These educational toys are both fun and effective, fostering creativity and learning in children.', 'bellaffelipe', i.id FROM railway.item AS i
# WHERE i.title = 'Children''s Educational Toys' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-06-01', 'Fair', 'The educational toys are fun and interactive but may not fully meet all learning needs.', 'BillyGarcia', i.id FROM railway.item AS i
# WHERE i.title = 'Children''s Educational Toys' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-07-14', 'Excellent', 'These educational toys are outstanding, effectively enhancing learning and creativity in children.', 'dollheartz', i.id FROM railway.item AS i
# WHERE i.title = 'Children''s Educational Toys' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-02-14', 'Good', 'The portable 3D printer is convenient and functional, though it may have limitations in print quality.', 'RobertSlay', i.id FROM railway.item AS i
# WHERE i.title = 'Portable 3D Printer' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-12-01', 'Excellent', 'This stylish laptop backpack is excellent for both students and professionals, offering durability and organization.', 'elon_musk', i.id FROM railway.item AS i
# WHERE i.title = 'Stylish Laptop Backpack' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-09-08', 'Excellent', 'The wireless Bluetooth speaker delivers exceptional sound quality, making it ideal for any setting.', 'karen_poor_reviews', i.id FROM railway.item AS i
# WHERE i.title = 'Wireless Bluetooth Speaker' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-06-15', 'Excellent', 'This wireless Bluetooth speaker impresses with its sound quality and design, suitable for various occasions.', 'bellaffelipe', i.id FROM railway.item AS i
# WHERE i.title = 'Wireless Bluetooth Speaker' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-06-24', 'Excellent', 'An excellent choice, this wireless Bluetooth speaker excels in both sound and aesthetics for outdoor and home use.', 'BillyGarcia', i.id FROM railway.item AS i
# WHERE i.title = 'Wireless Bluetooth Speaker' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-07-25', 'Good', 'The garden patio set is elegant and functional, but may require more comfort in seating.', 'PerryLee', i.id FROM railway.item AS i
# WHERE i.title = 'Garden Patio Set' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-03-07', 'Excellent', 'This camping hammock is fantastic for outdoor relaxation, being lightweight and easy to transport.', 'techy', i.id FROM railway.item AS i
# WHERE i.title = 'Camping Hammock' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-01-23', 'Fair', 'The kids'' educational puzzle is engaging and beneficial, though it may be too simple for some children.', 'admin', i.id FROM railway.item AS i
# WHERE i.title = 'Kids'' Educational Puzzle' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-07-11', 'Poor', 'The coffee maker with grinder falls short of expectations, as it struggles to deliver the promised flavor experience.', 'ChristineNguyen', i.id FROM railway.item AS i
# WHERE i.title = 'Coffee Maker with Grinder' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-04-04', 'Fair', 'The crafting supplies bundle offers a decent variety, but some materials may not meet the needs of all DIY enthusiasts.', 'techy', i.id FROM railway.item AS i
# WHERE i.title = 'Crafting Supplies Bundle' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-09-28', 'Fair', 'The crafting supplies bundle offers a decent variety, but some materials may not meet the needs of all DIY enthusiasts.', 'FrostyBite', i.id FROM railway.item AS i
# WHERE i.title = 'Crafting Supplies Bundle' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-01-04', 'Good', 'The smartphone tripod is a reliable choice, providing stability and adjustability for great photos and videos.', 'Gigi', i.id FROM railway.item AS i
# WHERE i.title = 'Smartphone Tripod' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-01-18', 'Fair', 'While the smartphone tripod is sturdy and adjustable, it may lack some features that advanced users desire.', 'elon_musk', i.id FROM railway.item AS i
# WHERE i.title = 'Smartphone Tripod' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-10-08', 'Excellent', 'The smartphone tripod excels in stability and adjustability, making it an excellent companion for photo and video capture.', 'dollheartz', i.id FROM railway.item AS i
# WHERE i.title = 'Smartphone Tripod' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-12-15', 'Excellent', 'The luxury skincare set is exceptional, delivering nourishing and rejuvenating benefits with its organic ingredients.', 'BillyGarcia', i.id FROM railway.item AS i
# WHERE i.title = 'Luxury Skincare Set' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-06-26', 'Good', 'The high-performance drone is a solid option for enthusiasts, though it may have a learning curve for beginners.', 'Gigi', i.id FROM railway.item AS i
# WHERE i.title = 'High-Performance Drone' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-04-12', 'Good', 'The high-performance drone is a solid option for enthusiasts, though it may have a learning curve for beginners.', 'd_trump', i.id FROM railway.item AS i
# WHERE i.title = 'High-Performance Drone' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-01-12', 'Excellent', 'The vintage vinyl records collection is outstanding, offering a nostalgic and curated selection for collectors.', 'RobertSlay', i.id FROM railway.item AS i
# WHERE i.title = 'Vintage Vinyl Records Collection' AND i.posted_by = 'admin'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-07-29', 'Good', 'A great selection for collectors that captures the essence of classic vinyl from the 70s and 80s.', 'dollheartz', i.id FROM railway.item AS i
# WHERE i.title = 'Vintage Vinyl Records Collection' AND i.posted_by = 'admin'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-11-13', 'Fair', 'While functional, the charger may struggle with larger devices or multiple charges in a day.', 'ChristineNguyen', i.id FROM railway.item AS i
# WHERE i.title = 'Portable Phone Charger' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-10-05', 'Good', 'A reliable option for on-the-go charging, providing convenience and portability.', 'dollheartz', i.id FROM railway.item AS i
# WHERE i.title = 'Portable Phone Charger' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-10-24', 'Good', 'This charger is a solid choice for travel, ensuring you stay powered up wherever you go.', 'BillyGarcia', i.id FROM railway.item AS i
# WHERE i.title = 'Portable Phone Charger' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-06-08', 'Excellent', 'An outstanding camping lantern that offers excellent brightness and durability for outdoor adventures.', 'FrostyBite', i.id FROM railway.item AS i
# WHERE i.title = 'Camping Lantern' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-03-31', 'Good', 'A well-rounded set of art supplies that encourages creativity, though some items may be better suited for older children.', 'elon_musk', i.id FROM railway.item AS i
# WHERE i.title = 'Kids'' Art Supplies' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-01-13', 'Good', 'This art supplies bundle is a delightful way to spark creativity in kids, though it may lack some advanced tools.', 'karen_poor_reviews', i.id FROM railway.item AS i
# WHERE i.title = 'Kids'' Art Supplies' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-03-16', 'Good', 'A solid gaming mouse that enhances performance with its customizable features, ideal for serious gamers.', 'FrostyBite', i.id FROM railway.item AS i
# WHERE i.title = 'Wireless Gaming Mouse' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-10-18', 'Good', 'This wireless gaming mouse is effective and user-friendly, making it a great addition to any gaming setup.', 'dollheartz', i.id FROM railway.item AS i
# WHERE i.title = 'Wireless Gaming Mouse' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-03-20', 'Excellent', 'An excellent vinyl record player that combines style with functionality, perfect for enjoying music.', 'karen_poor_reviews', i.id FROM railway.item AS i
# WHERE i.title = 'Vintage Vinyl Record Player' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-09-05', 'Fair', 'The vintage vinyl record player offers a stylish design, but its performance may not meet everyone''s expectations.', 'admin', i.id FROM railway.item AS i
# WHERE i.title = 'Vintage Vinyl Record Player' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-02-01', 'Excellent', 'This vintage vinyl record player delivers an excellent listening experience with its attractive design and built-in speakers.', 'nthPerson', i.id FROM railway.item AS i
# WHERE i.title = 'Vintage Vinyl Record Player' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-02-15', 'Poor', 'Unfortunately, the luxury leather wallet falls short in quality, making it hard to recommend despite its elegant appearance.', 'elon_musk', i.id FROM railway.item AS i
# WHERE i.title = 'Luxury Leather Wallet' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-10-13', 'Fair', 'The luxury leather wallet has a sleek design, but its functionality may not justify the price for some users.', 'PerryLee', i.id FROM railway.item AS i
# WHERE i.title = 'Luxury Leather Wallet' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-10-15', 'Excellent', 'This luxury leather wallet impresses with its elegant style and practical features, making it a worthwhile investment.', 'Gigi', i.id FROM railway.item AS i
# WHERE i.title = 'Luxury Leather Wallet' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-04-08', 'Excellent', 'The smartphone camera lens kit significantly enhances mobile photography, providing excellent quality lenses for creative shots.', 'd_trump', i.id FROM railway.item AS i
# WHERE i.title = 'Smartphone Camera Lens Kit' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-12-24', 'Good', 'The smartphone camera lens kit is a great addition for mobile photographers, though it may require some practice to fully utilize.', 'elon_musk', i.id FROM railway.item AS i
# WHERE i.title = 'Smartphone Camera Lens Kit' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-01-14', 'Excellent', 'This outdoor adventure backpack is perfect for hiking, offering excellent storage and comfort for outdoor enthusiasts.', 'ChristineNguyen', i.id FROM railway.item AS i
# WHERE i.title = 'Outdoor Adventure Backpack' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-12-24', 'Poor', 'Despite its appealing features, the outdoor adventure backpack may not perform as expected in real-world conditions.', 'bellaffelipe', i.id FROM railway.item AS i
# WHERE i.title = 'Outdoor Adventure Backpack' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-08-12', 'Excellent', 'The outdoor adventure backpack is a top-notch choice for anyone looking to explore the outdoors comfortably and efficiently.', 'nthPerson', i.id FROM railway.item AS i
# WHERE i.title = 'Outdoor Adventure Backpack' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-02-22', 'Poor', 'The Bluetooth Wireless Earphones fall short of expectations, offering disappointing sound quality despite their intended use for workouts and commuting.', 'techy', i.id FROM railway.item AS i
# WHERE i.title = 'Bluetooth Wireless Earphones' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-03-03', 'Fair', 'The Garden Composter Bin is a decent option for turning kitchen scraps into compost, but its design could use some improvements for better usability.', 'Gigi', i.id FROM railway.item AS i
# WHERE i.title = 'Garden Composter Bin' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-01-26', 'Fair', 'The Garden Composter Bin is a decent option for turning kitchen scraps into compost, but its design could use some improvements for better usability.', 'techy', i.id FROM railway.item AS i
# WHERE i.title = 'Garden Composter Bin' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-12-16', 'Excellent', 'The Garden Composter Bin excels at converting kitchen scraps into rich compost, making it an excellent eco-friendly choice for gardeners.', 'RobertSlay', i.id FROM railway.item AS i
# WHERE i.title = 'Garden Composter Bin' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-04-04', 'Excellent', 'The Electric Pressure Cooker is a fantastic appliance that significantly speeds up meal preparation with its versatile cooking modes.', 'FrostyBite', i.id FROM railway.item AS i
# WHERE i.title = 'Electric Pressure Cooker' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-03-04', 'Fair', 'The Electric Pressure Cooker performs adequately, but some users may find it lacking in certain features compared to other models.', 'bellaffelipe', i.id FROM railway.item AS i
# WHERE i.title = 'Electric Pressure Cooker' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-11-08', 'Fair', 'The Electric Pressure Cooker performs adequately, but some users may find it lacking in certain features compared to other models.', 'admin', i.id FROM railway.item AS i
# WHERE i.title = 'Electric Pressure Cooker' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-11-04', 'Excellent', 'The Adult Coloring Book is a wonderful tool for relaxation, featuring beautiful illustrations that effectively help reduce stress.', 'nthPerson', i.id FROM railway.item AS i
# WHERE i.title = 'Adult Coloring Book' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-08-04', 'Excellent', 'The Adult Coloring Book is a wonderful tool for relaxation, featuring beautiful illustrations that effectively help reduce stress.', 'dollheartz', i.id FROM railway.item AS i
# WHERE i.title = 'Adult Coloring Book' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-12-14', 'Excellent', 'The Adult Coloring Book is a wonderful tool for relaxation, featuring beautiful illustrations that effectively help reduce stress.', 'ChristineNguyen', i.id FROM railway.item AS i
# WHERE i.title = 'Adult Coloring Book' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-02-10', 'Good', 'Good quality PLA filament that offers a solid performance, though availability in more colors would be a plus.', 'd_trump', i.id FROM railway.item AS i
# WHERE i.title = '3D Printer PLA Filament' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-11-10', 'Poor', 'Disappointing experience with this PLA filament, as it failed to meet quality expectations despite its promising description.', 'karen_poor_reviews', i.id FROM railway.item AS i
# WHERE i.title = '3D Printer PLA Filament' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-03-24', 'Excellent', 'An excellent choice for outdoor enthusiasts, this backpack combines durability and ample space for all your gear.', 'techy', i.id FROM railway.item AS i
# WHERE i.title = 'Camping Backpack 50L' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-03-04', 'Excellent', 'This wireless gaming headset provides an outstanding audio experience and comfort, making it ideal for long gaming sessions.', 'karen_poor_reviews', i.id FROM railway.item AS i
# WHERE i.title = 'Wireless Gaming Headset' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-03-21', 'Poor', 'Unfortunately, this wireless gaming headset did not deliver on its promises, leading to a frustrating experience.', 'ChristineNguyen', i.id FROM railway.item AS i
# WHERE i.title = 'Wireless Gaming Headset' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-02-23', 'Fair', 'While the headset is comfortable, it has some drawbacks that may affect overall satisfaction during extended use.', 'techy', i.id FROM railway.item AS i
# WHERE i.title = 'Wireless Gaming Headset' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-05-23', 'Poor', 'This electric scooter has significant issues that overshadow its eco-friendly appeal and range claims.', 'admin', i.id FROM railway.item AS i
# WHERE i.title = 'Electric Scooter' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-01-24', 'Excellent', 'A fantastic eco-friendly electric scooter that excels in performance and range, perfect for urban commuting.', 'FrostyBite', i.id FROM railway.item AS i
# WHERE i.title = 'Electric Scooter' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-05-03', 'Poor', 'The portable projector underperformed, making it challenging to enjoy movie nights as intended.', 'FrostyBite', i.id FROM railway.item AS i
# WHERE i.title = 'Portable Projector' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-05-27', 'Excellent', 'An outstanding portable projector that delivers excellent picture quality, perfect for outdoor gatherings.', 'dollheartz', i.id FROM railway.item AS i
# WHERE i.title = 'Portable Projector' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-09-21', 'Good', 'A solid choice for outdoor movie nights or presentations, though it could benefit from more features.', 'techy', i.id FROM railway.item AS i
# WHERE i.title = 'Portable Projector' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-05-29', 'Fair', 'While stylish and durable, the water bottle could be improved in terms of insulation.', 'dollheartz', i.id FROM railway.item AS i
# WHERE i.title = 'Stainless Steel Water Bottle' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-02-12', 'Excellent', 'An outstanding water bottle that combines durability and style perfectly.', 'RobertSlay', i.id FROM railway.item AS i
# WHERE i.title = 'Stainless Steel Water Bottle' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-11-09', 'Good', 'These puzzles are engaging and educational for kids, though some pieces may be a bit challenging.', 'RobertSlay', i.id FROM railway.item AS i
# WHERE i.title = 'Kids Educational Puzzle' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-10-03', 'Excellent', 'Exceptional puzzles that not only entertain but also enhance children''s learning effectively.', 'admin', i.id FROM railway.item AS i
# WHERE i.title = 'Kids Educational Puzzle' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-05-21', 'Excellent', 'A beautifully designed backpack that is both stylish and functional for everyday use.', 'ChristineNguyen', i.id FROM railway.item AS i
# WHERE i.title = 'Luxury Leather Backpack' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-01-23', 'Fair', 'The soundbar delivers decent audio quality, but it may lack some advanced features.', 'bellaffelipe', i.id FROM railway.item AS i
# WHERE i.title = 'Bluetooth Soundbar' AND i.posted_by = 'admin'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-08-26', 'Fair', 'Good quality resistance bands, but their effectiveness may vary for advanced users.', 'RobertSlay', i.id FROM railway.item AS i
# WHERE i.title = 'Fitness Resistance Bands' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-02-13', 'Excellent', 'High-quality resistance bands that are perfect for effective strength training at home.', 'bellaffelipe', i.id FROM railway.item AS i
# WHERE i.title = 'Fitness Resistance Bands' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-05-07', 'Excellent', 'An excellent security camera that is easy to install and provides peace of mind.', 'admin', i.id FROM railway.item AS i
# WHERE i.title = 'Smart Home Security Camera' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-02-15', 'Excellent', 'An excellent choice for home security, this camera is easy to install and offers peace of mind.', 'elon_musk', i.id FROM railway.item AS i
# WHERE i.title = 'Smart Home Security Camera' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-03-29', 'Fair', 'While the camera is easy to install, it may have some limitations in features compared to competitors.', 'bellaffelipe', i.id FROM railway.item AS i
# WHERE i.title = 'Smart Home Security Camera' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-01-05', 'Excellent', 'These handcrafted jewelry pieces are truly unique and showcase exceptional artistry.', 'd_trump', i.id FROM railway.item AS i
# WHERE i.title = 'Artisan Handmade Jewelry' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-03-12', 'Excellent', 'The artisan jewelry stands out for its uniqueness and quality craftsmanship.', 'BillyGarcia', i.id FROM railway.item AS i
# WHERE i.title = 'Artisan Handmade Jewelry' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-05-10', 'Excellent', 'Each piece of this handmade jewelry is a testament to the skill of local artisans and offers something special.', 'bellaffelipe', i.id FROM railway.item AS i
# WHERE i.title = 'Artisan Handmade Jewelry' AND i.posted_by = 'techy'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-06-10', 'Poor', 'Unfortunately, this wireless car charger fails to deliver on its promises and is not worth the investment.', 'FrostyBite', i.id FROM railway.item AS i
# WHERE i.title = 'Wireless Car Charger' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-04-28', 'Fair', 'The portable Bluetooth speaker delivers solid performance, but it could benefit from improved sound quality.', 'ChristineNguyen', i.id FROM railway.item AS i
# WHERE i.title = 'Portable Bluetooth Speaker' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-01-10', 'Excellent', 'This portable Bluetooth speaker excels in both sound quality and battery life, making it a top pick for music lovers.', 'RobertSlay', i.id FROM railway.item AS i
# WHERE i.title = 'Portable Bluetooth Speaker' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-06-11', 'Excellent', 'A fantastic portable Bluetooth speaker that combines great sound with a waterproof design for outdoor use.', 'BillyGarcia', i.id FROM railway.item AS i
# WHERE i.title = 'Portable Bluetooth Speaker' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-10-25', 'Good', 'A well-designed puzzle set that provides both fun and educational value for kids, though it could use more variety.', 'RobertSlay', i.id FROM railway.item AS i
# WHERE i.title = 'Kids'' Puzzle Set' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-12-31', 'Excellent', 'This puzzle set is an excellent choice for kids, effectively combining fun and education to boost problem-solving skills.', 'karen_poor_reviews', i.id FROM railway.item AS i
# WHERE i.title = 'Kids'' Puzzle Set' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-03-01', 'Good', 'A good puzzle set that entertains and educates, though it could benefit from a few more challenging pieces.', 'admin', i.id FROM railway.item AS i
# WHERE i.title = 'Kids'' Puzzle Set' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-12-31', 'Excellent', 'An outstanding ergonomic office chair that prioritizes comfort and support, ideal for extended work periods.', 'ChristineNguyen', i.id FROM railway.item AS i
# WHERE i.title = 'Ergonomic Office Chair' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-02-02', 'Good', 'A good skincare set that delivers quality results; however, some products may not suit all skin types.', 'd_trump', i.id FROM railway.item AS i
# WHERE i.title = 'Luxury Skincare Set' AND i.posted_by = 'bellaffelipe'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-08-07', 'Excellent', 'This luxury skincare set is exceptional, offering high-quality products that truly enhance your complexion.', 'dollheartz', i.id FROM railway.item AS i
# WHERE i.title = 'Luxury Skincare Set' AND i.posted_by = 'bellaffelipe'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-10-04', 'Excellent', 'An excellent skincare set that provides everything you need for a luxurious skincare routine.', 'elon_musk', i.id FROM railway.item AS i
# WHERE i.title = 'Luxury Skincare Set' AND i.posted_by = 'bellaffelipe'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-11-15', 'Excellent', 'This 3D printing filament is top-notch, providing vibrant colors and consistent quality for all your projects.', 'admin', i.id FROM railway.item AS i
# WHERE i.title = '3D Printing Filament' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-12-28', 'Excellent', 'An excellent choice for 3D printing, this filament offers great quality and a variety of colors for creativity.', 'BillyGarcia', i.id FROM railway.item AS i
# WHERE i.title = '3D Printing Filament' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-09-09', 'Good', 'A good gimbal stabilizer that improves video quality significantly, though it may take some time to master.', 'RobertSlay', i.id FROM railway.item AS i
# WHERE i.title = 'Smartphone Gimbal Stabilizer' AND i.posted_by = 'BillyGarcia'
# ...
# WHERE i.title = 'Indoor Plant Care Kit' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-05-25', 'Poor', 'While it promises high capacity, the power bank fails to deliver reliable performance.', 'Gigi', i.id FROM railway.item AS i
# WHERE i.title = 'Portable Power Bank' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-03-29', 'Excellent', 'An outstanding power bank that ensures you stay charged on the go, highly recommended.', 'PerryLee', i.id FROM railway.item AS i
# WHERE i.title = 'Portable Power Bank' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-03-24', 'Excellent', 'A fantastic portable blender that makes smoothie preparation quick and easy.', 'd_trump', i.id FROM railway.item AS i
# WHERE i.title = 'Portable Blender' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-11-12', 'Excellent', 'An excellent choice for gamers, offering precision and customizable features.', 'd_trump', i.id FROM railway.item AS i
# WHERE i.title = 'Gaming Mouse' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-04-28', 'Good', 'A reliable gaming mouse with great features, though it may not stand out from competitors.', 'admin', i.id FROM railway.item AS i
# WHERE i.title = 'Gaming Mouse' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-05-03', 'Good', 'A practical and lightweight camping chair, ideal for outdoor enthusiasts.', 'techy', i.id FROM railway.item AS i
# WHERE i.title = 'Camping Chair' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-12-27', 'Excellent', 'Exceptional wireless earbuds that offer great sound quality and convenience.', 'bellaffelipe', i.id FROM railway.item AS i
# WHERE i.title = 'Wireless Earbuds' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-07-19', 'Fair', 'The wireless earbuds offer great sound quality, but some users may find connectivity issues under certain conditions.', 'Gigi', i.id FROM railway.item AS i
# WHERE i.title = 'Wireless Earbuds' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-01-10', 'Good', 'This yoga mat is eco-friendly and durable, making it a solid choice for various exercises.', 'dollheartz', i.id FROM railway.item AS i
# WHERE i.title = 'Yoga Mat' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-12-17', 'Good', 'This yoga mat is eco-friendly and durable, making it a solid choice for various exercises.', 'Gigi', i.id FROM railway.item AS i
# WHERE i.title = 'Yoga Mat' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-11-15', 'Poor', 'Despite being eco-friendly, this yoga mat fails to provide adequate grip and comfort.', 'elon_musk', i.id FROM railway.item AS i
# WHERE i.title = 'Yoga Mat' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-09-29', 'Excellent', 'The art supplies set is fantastic for aspiring artists, providing everything needed to start creating.', 'nthPerson', i.id FROM railway.item AS i
# WHERE i.title = 'Art Supplies Set' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-10-07', 'Fair', 'While the art supplies set is comprehensive, some items may not meet professional standards.', 'RobertSlay', i.id FROM railway.item AS i
# WHERE i.title = 'Art Supplies Set' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-10-18', 'Good', 'The smart garden kit is a great solution for indoor gardening, though it may require some learning to optimize use.', 'd_trump', i.id FROM railway.item AS i
# WHERE i.title = 'Smart Garden Kit' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-12-09', 'Excellent', 'The smart garden kit excels in convenience and effectiveness for growing fresh herbs and vegetables.', 'admin', i.id FROM railway.item AS i
# WHERE i.title = 'Smart Garden Kit' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-07-05', 'Good', 'This electric guitar is suitable for beginners, but some might find the sound quality lacking as they progress.', 'PerryLee', i.id FROM railway.item AS i
# WHERE i.title = 'Electric Guitar' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-02-02', 'Fair', 'The electric guitar is beginner-friendly, yet it may not satisfy more advanced players looking for better performance.', 'bellaffelipe', i.id FROM railway.item AS i
# WHERE i.title = 'Electric Guitar' AND i.posted_by = 'dollheartz'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-02-07', 'Poor', 'The throw blanket is disappointing in quality and does not meet expectations for luxury.', 'ChristineNguyen', i.id FROM railway.item AS i
# WHERE i.title = 'Luxury Throw Blanket' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-04-16', 'Excellent', 'This throw blanket offers exceptional comfort and quality, making it a great addition to any home.', 'PerryLee', i.id FROM railway.item AS i
# WHERE i.title = 'Luxury Throw Blanket' AND i.posted_by = 'nthPerson'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-04-03', 'Excellent', 'An outstanding fitness tracker that effectively helps in monitoring health and fitness goals with style.', 'karen_poor_reviews', i.id FROM railway.item AS i
# WHERE i.title = 'Fitness Tracker' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-01-06', 'Good', 'A solid fitness tracker that meets most needs but could use a few additional features for improvement.', 'nthPerson', i.id FROM railway.item AS i
# WHERE i.title = 'Fitness Tracker' AND i.posted_by = 'RobertSlay'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-06-16', 'Excellent', 'An excellent wooden puzzle that effectively promotes cognitive development in young children.', 'PerryLee', i.id FROM railway.item AS i
# WHERE i.title = 'Wooden Puzzle' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-01-08', 'Good', 'A good entry-level 3D printer that is easy to use, though it may have limitations for advanced users.', 'techy', i.id FROM railway.item AS i
# WHERE i.title = 'Compact 3D Printer' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-09-22', 'Excellent', 'A fantastic compact 3D printer with user-friendly setup and impressive print quality.', 'PerryLee', i.id FROM railway.item AS i
# WHERE i.title = 'Compact 3D Printer' AND i.posted_by = 'FrostyBite'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-03-06', 'Excellent', 'An excellent set of art supplies that inspires creativity in children and provides a variety of options.', 'FrostyBite', i.id FROM railway.item AS i
# WHERE i.title = 'Children''s Art Supplies Set' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-08-12', 'Good', 'A good art supplies set that encourages kids'' creativity, though it may lack some advanced tools.', 'd_trump', i.id FROM railway.item AS i
# WHERE i.title = 'Children''s Art Supplies Set' AND i.posted_by = 'karen_poor_reviews'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-08-10', 'Good', 'A reliable outdoor tent that is practical for camping, but may not perform well in extreme conditions.', 'elon_musk', i.id FROM railway.item AS i
# WHERE i.title = 'Outdoor Adventure Tent' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-11-30', 'Excellent', 'The Outdoor Adventure Tent is an outstanding choice for campers, combining lightweight design with robust weather resistance.', 'dollheartz', i.id FROM railway.item AS i
# WHERE i.title = 'Outdoor Adventure Tent' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-10-06', 'Excellent', 'This Outdoor Adventure Tent impresses with its lightweight and quick setup, making it ideal for camping trips.', 'bellaffelipe', i.id FROM railway.item AS i
# WHERE i.title = 'Outdoor Adventure Tent' AND i.posted_by = 'PerryLee'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-12-26', 'Excellent', 'The Wireless Gaming Router significantly improves gaming sessions with its high speed and low latency, making it a top pick.', 'bellaffelipe', i.id FROM railway.item AS i
# WHERE i.title = 'Wireless Gaming Router' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-03-28', 'Excellent', 'With its impressive range and performance, the Wireless Gaming Router is a must-have for serious gamers.', 'elon_musk', i.id FROM railway.item AS i
# WHERE i.title = 'Wireless Gaming Router' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-05-18', 'Excellent', 'This Wireless Gaming Router excels in delivering a seamless online gaming experience, thanks to its advanced features.', 'd_trump', i.id FROM railway.item AS i
# WHERE i.title = 'Wireless Gaming Router' AND i.posted_by = 'BillyGarcia'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-06-13', 'Good', 'The Vintage-Inspired Jewelry Box is beautifully crafted and practical, though it could benefit from additional storage options.', 'BillyGarcia', i.id FROM railway.item AS i
# WHERE i.title = 'Vintage-Inspired Jewelry Box' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-09-11', 'Excellent', 'This Vintage-Inspired Jewelry Box stands out for its exquisite design and functionality, perfect for any jewelry lover.', 'd_trump', i.id FROM railway.item AS i
# WHERE i.title = 'Vintage-Inspired Jewelry Box' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-03-09', 'Excellent', 'The Vintage-Inspired Jewelry Box combines elegance and practicality, making it a delightful addition to any collection.', 'elon_musk', i.id FROM railway.item AS i
# WHERE i.title = 'Vintage-Inspired Jewelry Box' AND i.posted_by = 'Gigi'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-09-04', 'Good', 'The Camping Cooking Set is a solid choice for outdoor cooking, though some may find it lacks a few essential tools.', 'nthPerson', i.id FROM railway.item AS i
# WHERE i.title = 'Camping Cooking Set' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-09-09', 'Fair', 'While the Camping Cooking Set is lightweight and convenient, its durability could be improved for more rugged use.', 'dollheartz', i.id FROM railway.item AS i
# WHERE i.title = 'Camping Cooking Set' AND i.posted_by = 'ChristineNguyen'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2023-11-08', 'Good', 'The portable Bluetooth projector is a solid choice for on-the-go entertainment, though it could benefit from improved brightness.', 'BillyGarcia', i.id FROM railway.item AS i
# WHERE i.title = 'Portable Bluetooth Projector' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-07-19', 'Good', 'This compact projector is great for movies and presentations, but some users may find the battery life lacking.', 'Gigi', i.id FROM railway.item AS i
# WHERE i.title = 'Portable Bluetooth Projector' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-07-24', 'Good', 'A reliable option for portable viewing, but it may not meet all expectations for larger venues.', 'ChristineNguyen', i.id FROM railway.item AS i
# WHERE i.title = 'Portable Bluetooth Projector' AND i.posted_by = 'elon_musk'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-11-13', 'Fair', 'While the STEM toy set is engaging and educational, some components may require adult supervision for younger children.', 'PerryLee', i.id FROM railway.item AS i
# WHERE i.title = 'Educational STEM Toy Set' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2025-05-21', 'Excellent', 'This educational STEM toy set excels in promoting hands-on learning and creativity for kids, making it a fantastic choice.', 'dollheartz', i.id FROM railway.item AS i
# WHERE i.title = 'Educational STEM Toy Set' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# INSERT IGNORE INTO railway.review (`review_date`, `score`, `remark`, `user_id`, `item_id`)
# SELECT '2024-10-23', 'Excellent', 'An outstanding STEM toy set that effectively combines fun and education, highly recommended for young learners.', 'FrostyBite', i.id FROM railway.item AS i
# WHERE i.title = 'Educational STEM Toy Set' AND i.posted_by = 'd_trump'
# ORDER BY i.id DESC
# LIMIT 1;
# COMMIT;

# %% [markdown]
# ##### Recalculate and persist star_rating for all items

# %%
# Assumes `app` was already created and `db` initialized earlier in the notebook.
from models import db, Item

with app.app_context():
    # Ensure session sees the latest DB state (e.g., after Workbench inserts)
    db.session.expire_all()

    total = 0
    updated = 0
    for item in Item.query.yield_per(200):
        total += 1
        new_rating = item.calculate_star_rating()  # computes average from existing reviews
        if item.star_rating != new_rating:
            item.star_rating = new_rating
            updated += 1

    db.session.commit()
    print(f"Recalculated star_rating for {total} items. Updated {updated} rows.")

    # Preview a few items
    sample = Item.query.order_by(Item.id.desc()).limit(5).all()
    for it in sample:
        print(f"{it.id}: {it.title} -> {it.star_rating}")
# Out:
# Recalculated star_rating for 121 items. Updated 100 rows.
# 121: Educational STEM Toy Set -> 4.17
# 120: Portable Bluetooth Projector -> 3.75
# 119: Camping Cooking Set -> 3.12
# 118: Vintage-Inspired Jewelry Box -> 4.58
# 117: Wireless Gaming Router -> 5.0

# %% [markdown]
# ##### Generate Follower/Follow Sample Data

# %%
import random

# If usernames isn't defined for any reason, re-query
try:
    assert usernames and isinstance(usernames, list)
except Exception:
    from flask import Flask
    from models import db, User
    app = Flask(__name__)
    app.config.update(
        SQLALCHEMY_DATABASE_URI=os.getenv("SHARED_DATABASE_URL") or os.getenv("DATABASE_URL"),
        SQLALCHEMY_TRACK_MODIFICATIONS=False,
    )
    db.init_app(app)
    with app.app_context():
        usernames = [u.username for u in User.query.order_by(User.username).all()]

N = len(usernames)
if N < 2:
    print("Not enough users to generate follows.")
else:
    k_min = min(3, max(0, N - 1))   # Minimum of 3 followers/follows for each user
    k_max = min(10, max(0, N - 1))  # Maximum of 10 followers/follows for each user

    idx_of = {u: i for i, u in enumerate(usernames)}
    follows = {u: set() for u in usernames}    # u -> set of followees
    in_deg  = {u: 0 for u in usernames}        # follower counts

    # Step 1: base ring(s) to guarantee everyone has at least k_min in/out
    # For d = 1..k_min, connect i -> (i + d) mod N
    for d in range(1, k_min + 1):
        for i, u in enumerate(usernames):
            v = usernames[(i + d) % N]
            if v != u and v not in follows[u]:
                follows[u].add(v)
                in_deg[v] += 1

    # Step 2: add random extras up to k_max for both in/out, respecting caps
    for u in usernames:
        cur_out = len(follows[u])
        extra_budget = max(0, k_max - cur_out)
        extra_out = random.randint(0, extra_budget) if extra_budget > 0 else 0

        trials = 0
        while extra_out > 0 and trials < 5 * N:
            trials += 1
            v = random.choice(usernames)
            if v == u:
                continue
            if v in follows[u]:
                continue
            if in_deg[v] >= k_max:
                continue
            follows[u].add(v)
            in_deg[v] += 1
            extra_out -= 1

    # Sanity checks: no self follows, no duplicates
    pairs = []
    seen = set()
    for u, outs in follows.items():
        for v in outs:
            if u == v:
                continue
            key = (u, v)
            if key in seen:
                continue
            seen.add(key)
            pairs.append(key)

    # Build artifact for later use
    generated_follows = [{"follower_id": u, "followee_id": v} for (u, v) in pairs]

    # Summary
    out_deg = {u: len(follows[u]) for u in usernames}
    min_out, max_out = min(out_deg.values()), max(out_deg.values())
    min_in, max_in   = min(in_deg.values()),  max(in_deg.values())
    print(f"Users: {N}")
    print(f"Follow pairs: {len(generated_follows)}")
    print(f"Out-degree (followees) range: {min_out}..{max_out} (target {k_min}..{k_max})")
    print(f"In-degree (followers) range: {min_in}..{max_in} (target {k_min}..{k_max})")
    print("Sample:", generated_follows[:5])

    # Emit SQL for MySQL Workbench
    def sql_quote(s: str) -> str:
        if s is None:
            return "NULL"
        s = str(s).replace("\\", "\\\\").replace("'", "''").replace("\n", " ")
        return f"'{s}'"

    lines = []
    lines.append("-- Insert generated follows (username->username). Avoids duplicates with INSERT IGNORE.")
    lines.append("START TRANSACTION;")
    for rel in generated_follows:
        follower = sql_quote(rel["follower_id"])
        followee = sql_quote(rel["followee_id"])
        lines.append(
            "INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) "
            f"VALUES ({follower}, {followee});"
            # "INSERT IGNORE INTO comp440db.follow (`follower_username`, `user_username`) "
            # f"VALUES ({follower}, {followee});"
        )
    lines.append("COMMIT;")

    sql_insert_follows = "\n".join(lines)
    print(sql_insert_follows)
# Out:
# Users: 14
# Follow pairs: 84
# Out-degree (followees) range: 4..9 (target 3..10)
# In-degree (followers) range: 5..8 (target 3..10)
# Sample: [{'follower_id': 'admin', 'followee_id': 'PerryLee'}, {'follower_id': 'admin', 'followee_id': 'elon_musk'}, {'follower_id': 'admin', 'followee_id': 'BillyGarcia'}, {'follower_id': 'admin', 'followee_id': 'FrostyBite'}, {'follower_id': 'admin', 'followee_id': 'bellaffelipe'}]
# -- Insert generated follows (username->username). Avoids duplicates with INSERT IGNORE.
# START TRANSACTION;
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('admin', 'PerryLee');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('admin', 'elon_musk');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('admin', 'BillyGarcia');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('admin', 'FrostyBite');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('admin', 'bellaffelipe');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('admin', 'ChristineNguyen');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('bellaffelipe', 'PerryLee');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('bellaffelipe', 'elon_musk');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('bellaffelipe', 'BillyGarcia');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('bellaffelipe', 'FrostyBite');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('bellaffelipe', 'Gigi');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('bellaffelipe', 'karen_poor_reviews');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('bellaffelipe', 'RobertSlay');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('bellaffelipe', 'ChristineNguyen');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('bellaffelipe', 'd_trump');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('BillyGarcia', 'dollheartz');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('BillyGarcia', 'nthPerson');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('BillyGarcia', 'ChristineNguyen');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('BillyGarcia', 'd_trump');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('ChristineNguyen', 'dollheartz');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('ChristineNguyen', 'nthPerson');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('ChristineNguyen', 'elon_musk');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('ChristineNguyen', 'd_trump');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('d_trump', 'techy');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('d_trump', 'elon_musk');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('d_trump', 'PerryLee');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('d_trump', 'dollheartz');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('d_trump', 'FrostyBite');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('d_trump', 'Gigi');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('d_trump', 'karen_poor_reviews');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('d_trump', 'bellaffelipe');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('d_trump', 'nthPerson');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('dollheartz', 'FrostyBite');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('dollheartz', 'elon_musk');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('dollheartz', 'Gigi');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('dollheartz', 'd_trump');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('elon_musk', 'PerryLee');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('elon_musk', 'dollheartz');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('elon_musk', 'FrostyBite');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('elon_musk', 'BillyGarcia');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('elon_musk', 'Gigi');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('elon_musk', 'karen_poor_reviews');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('elon_musk', 'd_trump');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('FrostyBite', 'elon_musk');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('FrostyBite', 'Gigi');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('FrostyBite', 'karen_poor_reviews');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('FrostyBite', 'bellaffelipe');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('FrostyBite', 'nthPerson');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('FrostyBite', 'ChristineNguyen');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('Gigi', 'techy');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('Gigi', 'admin');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('Gigi', 'PerryLee');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('Gigi', 'karen_poor_reviews');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('Gigi', 'bellaffelipe');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('Gigi', 'RobertSlay');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('Gigi', 'nthPerson');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('karen_poor_reviews', 'FrostyBite');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('karen_poor_reviews', 'RobertSlay');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('karen_poor_reviews', 'nthPerson');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('karen_poor_reviews', 'PerryLee');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('nthPerson', 'techy');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('nthPerson', 'PerryLee');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('nthPerson', 'admin');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('nthPerson', 'dollheartz');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('nthPerson', 'BillyGarcia');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('nthPerson', 'Gigi');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('nthPerson', 'bellaffelipe');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('nthPerson', 'RobertSlay');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('nthPerson', 'd_trump');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('PerryLee', 'RobertSlay');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('PerryLee', 'techy');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('PerryLee', 'admin');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('PerryLee', 'BillyGarcia');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('RobertSlay', 'techy');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('RobertSlay', 'PerryLee');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('RobertSlay', 'elon_musk');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('RobertSlay', 'admin');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('RobertSlay', 'dollheartz');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('RobertSlay', 'bellaffelipe');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('techy', 'admin');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('techy', 'dollheartz');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('techy', 'BillyGarcia');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('techy', 'bellaffelipe');
# INSERT IGNORE INTO railway.follow (`follower_username`, `user_username`) VALUES ('techy', 'ChristineNguyen');
# COMMIT;
